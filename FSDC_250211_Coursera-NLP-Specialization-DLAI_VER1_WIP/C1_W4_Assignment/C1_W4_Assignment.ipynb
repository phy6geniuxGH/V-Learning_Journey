# %% [markdown]
# # Assignment 4 - Naive Machine Translation and LSH
#
# You will now implement your first machine translation system and then you
# will see how locality sensitive hashing works. Let's get started by importing
# the required functions!
#
# If you are running this notebook in your local computer, don't forget to
# download the twitter samples and stopwords from nltk.
#
# ```
# nltk.download('stopwords')
# nltk.download('twitter_samples')
# ```
#
# ## Important Note on Submission to the AutoGrader
#
# Before submitting your assignment to the AutoGrader, please make sure you are not doing the following:
#
# 1. You have not added any _extra_ `print` statement(s) in the assignment.
# 2. You have not added any _extra_ code cell(s) in the assignment.
# 3. You have not changed any of the function parameters.
# 4. You are not using any global variables inside your graded exercises. Unless specifically instructed to do so, please refrain from it and use the local variables instead.
# 5. You are not changing the assignment code where it is not required, like creating _extra_ variables.
#
# If you do any of the following, you will get something like, `Grader Error: Grader feedback not found` (or similarly unexpected) error upon submitting your assignment. Before asking for help/debugging the errors in your assignment, check for these first. If this is the case, and you don't remember the changes you have made, you can get a fresh copy of the assignment by following these [instructions](https://www.coursera.org/learn/classification-vector-spaces-in-nlp/supplement/YLuAg/h-ow-to-refresh-your-workspace).

# %% [markdown]
# ## Table of Contents
#
# - [1. The Word Embeddings Data for English and French Words](#1)
#   - [1.1 Generate Embedding and Transform Matrices](#1-1)
#       - [Exercise 1 - get_matrices (UNQ_C1)](#ex-1)
# - [2 - Translations](#2)
#   - [2.1 - Translation as Linear Transformation of Embeddings](#2-1)
#       - [Exercise 2 - compute_loss (UNQ_C3)](#ex-2)
#       - [Exercise 3 - compute_gradient (UNQ_C4)](#ex-3)
#       - [Exercise 4 - align_embeddings (UNQ_C5)](#ex-4)
#   - [2.2 - Testing the Translation](#2-2)
#       - [Exercise 5 - nearest_neighbor (UNQ_C8)](#ex-5)
#       - [Exercise 6 - test_vocabulary (UNQ_C10)](#ex-6)
# - [3 - LSH and Document Search](#3)
#   - [3.1 - Getting the Document Embeddings](#3-1)
#       - [Exercise 7 - get_document_embedding (UNQ_C12)](#ex-7)
#       - [Exercise 8 - get_document_vecs (UNQ_C14)](#ex-8)
#   - [3.2 - Looking up the Tweets](#3-2)
#   - [3.3 - Finding the most Similar Tweets with LSH](#3-3)
#   - [3.4 - Getting the Hash Number for a Vector](#3-4)
#       - [Exercise 9 - hash_value_of_vector (UNQ_C17)](#ex-9)
#   - [3.5 - Creating a Hash Table](#3-5)
#       - [Exercise 10 - make_hash_table (UNQ_C19)](#ex-10)
#   - [3.6 - Creating all Hash Tables](#3-6)
#       - [Exercise 11 - approximate_knn (UNQ_C21)](#ex-11)

# %%
import pdb
import pickle
import string

import time

import nltk
import numpy as np
from nltk.corpus import stopwords, twitter_samples

from utils import (cosine_similarity, get_dict,
                   process_tweet)
from os import getcwd

import w4_unittest

# %%
# add folder, tmp2, from our local workspace containing pre-downloaded corpora files to nltk's data path
filePath = f"{getcwd()}/tmp2/"
nltk.data.path.append(filePath)

# %% [markdown]
# <a name="1"></a>
#
# # 1. The Word Embeddings Data for English and French Words
#
# Write a program that translates English to French.
#
# ## The Data
#
# The full dataset for English embeddings is about 3.64 gigabytes, and the French
# embeddings are about 629 megabytes. To prevent the Coursera workspace from
# crashing, we've extracted a subset of the embeddings for the words that you'll
# use in this assignment.

# %% [markdown]
# #### The subset of data
#
# To do the assignment on the Coursera workspace, we'll use the subset of word embeddings.

# %%
en_embeddings_subset = pickle.load(open("./data/en_embeddings.p", "rb"))
fr_embeddings_subset = pickle.load(open("./data/fr_embeddings.p", "rb"))

# %% [markdown]
# #### Look at the data
#
# * en_embeddings_subset: the key is an English word, and the value is a
# 300 dimensional array, which is the embedding for that word.
# ```
# 'the': array([ 0.08007812,  0.10498047,  0.04980469,  0.0534668 , -0.06738281, ....
# ```
#
# * fr_embeddings_subset: the key is a French word, and the value is a 300
# dimensional array, which is the embedding for that word.
# ```
# 'la': array([-6.18250e-03, -9.43867e-04, -8.82648e-03,  3.24623e-02,...
# ```

# %% [markdown]
# #### Load two dictionaries mapping the English to French words
# * A training dictionary
# * and a testing dictionary.

# %%
# loading the english to french dictionaries
en_fr_train = get_dict('./data/en-fr.train.txt')
print('The length of the English to French training dictionary is', len(en_fr_train))
en_fr_test = get_dict('./data/en-fr.test.txt')
print('The length of the English to French test dictionary is', len(en_fr_test))
# Out:
# The length of the English to French training dictionary is 5000
# The length of the English to French test dictionary is 1500

# %% [markdown]
# #### Looking at the English French dictionary
#
# * `en_fr_train` is a dictionary where the key is the English word and the value
# is the French translation of that English word.
# ```
# {'the': 'la',
#  'and': 'et',
#  'was': 'était',
#  'for': 'pour',
# ```
#
# * `en_fr_test` is similar to `en_fr_train`, but is a test set.  We won't look at it
# until we get to testing.

# %% [markdown]
# <a name="1-1"></a>
# ### 1.1 Generate Embedding and Transform Matrices
#
# <a name="ex-1"></a>
# ### Exercise 1 - get_matrices
#
# Translating English dictionary to French by using embeddings.
#
# You will now implement a function `get_matrices`, which takes the loaded data
# and returns matrices `X` and `Y`.
#
# Inputs:
# - `en_fr` : English to French dictionary
# - `en_embeddings` : English to embeddings dictionary
# - `fr_embeddings` : French to embeddings dictionary
#
# Returns:
# - Matrix `X` and matrix `Y`, where each row in X is the word embedding for an
# english word, and the same row in Y is the word embedding for the French
# version of that English word.
#
# <div style="width:image width px; font-size:100%; text-align:center;">
# <img src='./images/X_to_Y.jpg' alt="alternate text" width="width" height="height" style="width:800px;height:200px;" /> Figure 1 </div>
#
# Use the `en_fr` dictionary to ensure that the ith row in the `X` matrix
# corresponds to the ith row in the `Y` matrix.

# %% [markdown]
# **Instructions**: Complete the function `get_matrices()`:
# * Iterate over English words in `en_fr` dictionary.
# * Check if the word have both English and French embedding.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
#     <p>
#         <ul>
#             <li><a href="https://realpython.com/python-sets/#set-size-and-membership" >Sets</a> are useful data structures that can be used to check if an item is a member of a group.</li>
#             <li>You can get words which are embedded into the language by using <a href="https://www.w3schools.com/python/ref_dictionary_keys.asp"> keys</a> method.</li>
#             <li>Keep vectors in `X` and `Y` sorted in list. You can use <a href="https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ma.vstack.html"> np.vstack()</a> to merge them into the numpy matrix. </li>
#             <li><a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.vstack.html">numpy.vstack</a> stacks the items in a list as rows in a matrix.</li>
#         </ul>
#     </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def get_matrices(en_fr, french_vecs, english_vecs):
    """
    Creates matrices of word embeddings for English and French words that are mapped to each other.
    
    Inputs:
        en_fr: Dictionary mapping English words to French words.
        french_vecs: Dictionary of French word embeddings.
        english_vecs: Dictionary of English word embeddings.
    
    Outputs: 
        X: Matrix with each row being the embedding of an English word. Shape is (number_of_words, embedding_size).
        Y: Matrix with each row being the embedding of the corresponding French word. Shape matches X.
    
    Note:
        This function does not compute or return a projection matrix.
    """

    ### START CODE HERE ###

    # X_l and Y_l are lists of the english and french word embeddings
    X_l = list()
    Y_l = list()

    # get the english words (the keys in the dictionary) and store in a set()
    english_set = set(english_vecs.keys())

    # get the french words (keys in the dictionary) and store in a set()
    french_set = set(french_vecs.keys())

    # store the french words that are part of the english-french dictionary (these are the values of the dictionary)
    french_words = set(en_fr.values())

    # loop through all english, french word pairs in the english french dictionary
    for en_word, fr_word in en_fr.items():

        # check that the french word has an embedding and that the english word has an embedding
        if fr_word in french_set and en_word in english_set:

            # get the english embedding
            en_vec = english_vecs[en_word]

            # get the french embedding
            fr_vec = french_vecs[fr_word]

            # add the english embedding to the list
            X_l.append(en_vec)

            # add the french embedding to the list
            Y_l.append(fr_vec)

    # stack the vectors of X_l into a matrix X
    X = np.vstack(X_l)

    # stack the vectors of Y_l into a matrix Y
    Y = np.vstack(Y_l)
    ### END CODE HERE ###

    return X, Y

# %% [markdown]
# Now we will use function `get_matrices()` to obtain sets `X_train` and `Y_train`
# of English and French word embeddings into the corresponding vector space models.

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# getting the training set:
X_train, Y_train = get_matrices(
    en_fr_train, fr_embeddings_subset, en_embeddings_subset)

# %%
# Test your function
w4_unittest.test_get_matrices(get_matrices)
# Out:
#  All tests passed

# %% [markdown]
# <a name="2"></a>
#
# ## 2 - Translations
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='./images/e_to_f.jpg' alt="alternate text" width="width" height="height" style="width:700px;height:200px;" /> Figure 2 </div>
#
# Write a program that translates English words to French words using word embeddings and vector space models.
#
# <a name="2-1"></a>
# ### 2.1 - Translation as Linear Transformation of Embeddings
#
# Given dictionaries of English and French word embeddings you will create a transformation matrix `R`
# * Given an English word embedding, $\mathbf{e}$, you can multiply $\mathbf{eR}$ to get a new word embedding $\mathbf{f}$.
#     * Both $\mathbf{e}$ and $\mathbf{f}$ are [row vectors](https://en.wikipedia.org/wiki/Row_and_column_vectors).
# * You can then compute the nearest neighbors to `f` in the french embeddings and recommend the word that is most similar to the transformed word embedding.

# %% [markdown]
# #### Describing translation as the minimization problem
#
# Find a matrix `R` that minimizes the following equation.
#
# $$\arg \min _{\mathbf{R}}\| \mathbf{X R} - \mathbf{Y}\|_{F}\tag{1} $$
#
# #### Frobenius norm
#
# The Frobenius norm of a matrix $A$ (assuming it is of dimension $m,n$) is defined as the square root of the sum of the absolute squares of its elements:
#
# $$\|\mathbf{A}\|_{F} \equiv \sqrt{\sum_{i=1}^{m} \sum_{j=1}^{n}\left|a_{i j}\right|^{2}}\tag{2}$$

# %% [markdown]
# #### Actual loss function
# In the real world applications, the Frobenius norm loss:
#
# $$\| \mathbf{XR} - \mathbf{Y}\|_{F}$$
#
# is often replaced by it's squared value divided by $m$:
#
# $$ \frac{1}{m} \|  \mathbf{X R} - \mathbf{Y} \|_{F}^{2}$$
#
# where $m$ is the number of examples (rows in $\mathbf{X}$).
#
# * The same R is found when using this loss function versus the original Frobenius norm.
# * The reason for taking the square is that it's easier to compute the gradient of the squared Frobenius.
# * The reason for dividing by $m$ is that we're more interested in the average loss per embedding than the  loss for the entire training set.
#     * The loss for all training set increases with more words (training examples),
#     so taking the average helps us to track the average loss regardless of the size of the training set.

# %% [markdown]
# ##### [Optional] Detailed explanation why we use norm squared instead of the norm:
# <details>
# <summary>
#     Click for optional details
# </summary>
#     <p>
#         <ul>
#             <li>The norm is always nonnegative (we're summing up absolute values), and so is the square.
#             <li> When we take the square of all non-negative (positive or zero) numbers, the order of the data is preserved.
#             <li> For example, if 3 > 2, 3^2 > 2^2
#             <li> Using the norm or squared norm in gradient descent results in the same <i>location</i> of the minimum.
#             <li> Squaring cancels the square root in the Frobenius norm formula. Because of the <a href="https://en.wikipedia.org/wiki/Chain_rule"> chain rule</a>, we would have to do more calculations if we had a square root in our expression for summation.
#             <li> Dividing the function value by the positive number doesn't change the optimum of the function, for the same reason as described above.
#             <li> We're interested in transforming English embedding into the French. Thus, it is more important to measure average loss per embedding than the loss for the entire dictionary (which increases as the number of words in the dictionary increases).
#         </ul>
#     </p>

# %% [markdown]
# #### Implementing translation mechanism described in this section.
#
# <a name="ex-2"></a>
# ### Exercise 2 - compute_loss
#
# #### Step 1: Computing the loss
# * The loss function will be squared Frobenius norm of the difference between
# matrix and its approximation, divided by the number of training examples $m$.
# * Its formula is:
# $$ L(X, Y, R)=\frac{1}{m}\sum_{i=1}^{m} \sum_{j=1}^{n}\left( a_{i j} \right)^{2}$$
#
# where $a_{i j}$ is value in $i$th row and $j$th column of the matrix $\mathbf{XR}-\mathbf{Y}$.

# %% [markdown]
# #### Instructions: complete the `compute_loss()` function
#
# * Compute the approximation of `Y` by matrix multiplying `X` and `R`
# * Compute difference `XR - Y`
# * Compute the squared Frobenius norm of the difference and divide it by $m$.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#    <li> Useful functions:
#        <a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.dot.html">Numpy dot </a>,
#        <a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.sum.html">Numpy sum</a>,
#        <a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.square.html">Numpy square</a>,
#        <a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.linalg.norm.html">Numpy norm</a>
#     </li>
#    <li> Be careful about which operation is elementwise and which operation is a matrix multiplication.</li>
#    <li> Try to use matrix operations instead of the numpy norm function.  If you choose to use norm function, take care of extra arguments and that it's returning loss squared, and not the loss itself.</li>
#
# </ul>
# </p>

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def compute_loss(X, Y, R):
    '''
    Inputs: 
        X: a matrix of dimension (m,n) where the columns are the English embeddings.
        Y: a matrix of dimension (m,n) where the columns correspong to the French embeddings.
        R: a matrix of dimension (n,n) - transformation matrix from English to French vector space embeddings.
    Outputs:
        L: a matrix of dimension (m,n) - the value of the loss function for given X, Y and R.
    '''
    ### START CODE HERE ###
    # m is the number of rows in X
    m = X.shape[0]
        
    # diff is XR - Y    
    diff = np.matmul(X,R) - Y #or X@R - Y

    # diff_squared is the element-wise square of the difference    
    diff_squared = diff**2

    # sum_diff_squared is the sum of the squared elements
    sum_diff_squared = np.sum(diff_squared)

    # loss i is the sum_diff_squared divided by the number of examples (m)
    loss = (1/m)*sum_diff_squared
    ### END CODE HERE ###
    return loss

# %%
# Testing your implementation.
np.random.seed(123)
m = 10
n = 5
X = np.random.rand(m, n)
Y = np.random.rand(m, n) * .1
R = np.random.rand(n, n)
print(f"Expected loss for an experiment with random matrices: {compute_loss(X, Y, R):.4f}" )
# Out:
# Expected loss for an experiment with random matrices: 8.1866

# %% [markdown]
# **Expected output:**
# ```
# Expected loss for an experiment with random matrices: 8.1866
# ```

# %%
# Test your function
w4_unittest.test_compute_loss(compute_loss)
# Out:
#  All tests passed

# %% [markdown]
# <a name="ex-3"></a>
# ### Exercise 3 - compute_gradient
#
# #### Step 2: Computing the gradient of loss with respect to transform matrix R
#
# * Calculate the gradient of the loss with respect to transform matrix `R`.
# * The gradient is a matrix that encodes how much a small change in `R`
# affect the change in the loss function.
# * The gradient gives us the direction in which we should decrease `R`
# to minimize the loss.
# * $m$ is the number of training examples (number of rows in $X$).
# * The formula for the gradient of the loss function $𝐿(𝑋,𝑌,𝑅)$ is:
#
# $$\frac{d}{dR}𝐿(𝑋,𝑌,𝑅)=\frac{d}{dR}\Big(\frac{1}{m}\| X R -Y\|_{F}^{2}\Big) = \frac{2}{m}X^{T} (X R - Y)$$
#
# **Instructions**: Complete the `compute_gradient` function below.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
#     <ul>
#     <li><a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.matrix.T.html" > Transposing in numpy </a></li>
#     <li><a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.shape.html" > Finding out the dimensions</a> of matrices in numpy </li>
#     <li>Remember to use numpy.dot for matrix multiplication </li>
#     </ul>
# </p>

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def compute_gradient(X, Y, R):
    '''
    Inputs: 
        X: a matrix of dimension (m,n) where the columns are the English embeddings.
        Y: a matrix of dimension (m,n) where the columns correspong to the French embeddings.
        R: a matrix of dimension (n,n) - transformation matrix from English to French vector space embeddings.
    Outputs:
        g: a scalar value - gradient of the loss function L for given X, Y and R.
    '''
    ### START CODE HERE ###
    # m is the number of rows in X
    m = X.shape[0]

    # gradient is X^T(XR - Y) * 2/m    
    gradient = np.dot((X.T),(X@R - Y))*(2/m)
    
    ### END CODE HERE ###
    return gradient

# %%
# Testing your implementation.
np.random.seed(123)
m = 10
n = 5
X = np.random.rand(m, n)
Y = np.random.rand(m, n) * .1
R = np.random.rand(n, n)
gradient = compute_gradient(X, Y, R)
print(f"First row of the gradient matrix: {gradient[0]}")
# Out:
# First row of the gradient matrix: [1.3498175  1.11264981 0.69626762 0.98468499 1.33828969]

# %% [markdown]
# **Expected output:**
# ```
# First row of the gradient matrix: [1.3498175  1.11264981 0.69626762 0.98468499 1.33828969]
# ```

# %%
# Test your function
w4_unittest.test_compute_gradient(compute_gradient)
# Out:
#  All tests passed

# %% [markdown]
# #### Step 3: Finding the optimal R with Gradient Descent Algorithm
#
# ##### Gradient Descent
#
# [Gradient descent](https://ml-cheatsheet.readthedocs.io/en/latest/gradient_descent.html) is an iterative algorithm which is used in searching for the optimum of the function.
# * Earlier, we've mentioned that the gradient of the loss with respect to the matrix encodes how much a tiny change in some coordinate of that matrix affect the change of loss function.
# * Gradient descent uses that information to iteratively change matrix `R` until we reach a point where the loss is minimized.

# %% [markdown]
# #### Training with a fixed number of iterations
#
# Most of the time we iterate for a fixed number of training steps rather than iterating until the loss falls below a threshold.
#
# ##### OPTIONAL: explanation for fixed number of iterations
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>click here for detailed discussion</b></font>
# </summary>
# <p>
# <ul>
#     <li> You cannot rely on training loss getting low -- what you really want is the validation loss to go down, or validation accuracy to go up. And indeed - in some cases people train until validation accuracy reaches a threshold, or -- commonly known as "early stopping" -- until the validation accuracy starts to go down, which is a sign of over-fitting.
#     </li>
#     <li>
#     Why not always do "early stopping"? Well, mostly because well-regularized models on larger data-sets never stop improving. Especially in NLP, you can often continue training for months and the model will continue getting slightly and slightly better. This is also the reason why it's hard to just stop at a threshold -- unless there's an external customer setting the threshold, why stop, where do you put the threshold?
#     </li>
#     <li>Stopping after a certain number of steps has the advantage that you know how long your training will take - so you can keep some sanity and not train for months. You can then try to get the best performance within this time budget. Another advantage is that you can fix your learning rate schedule -- e.g., lower the learning rate at 10% before finish, and then again more at 1% before finishing. Such learning rate schedules help a lot, but are harder to do if you don't know how long you're training.
#     </li>
# </ul>
# </p>

# %% [markdown]
# Pseudocode:
# 1. Calculate gradient $g$ of the loss with respect to the matrix $R$.
# 2. Update $R$ with the formula:
# $$R_{\text{new}}= R_{\text{old}}-\alpha g$$
#
# Where $\alpha$ is the learning rate, which is a scalar.

# %% [markdown]
# #### Learning Rate
#
# * The learning rate or "step size" $\alpha$ is a coefficient which decides how much we want to change $R$ in each step.
# * If we change $R$ too much, we could skip the optimum by taking too large of a step.
# * If we make only small changes to $R$, we will need many steps to reach the optimum.
# * Learning rate $\alpha$ is used to control those changes.
# * Values of $\alpha$ are chosen depending on the problem, and we'll use `learning_rate`$=0.0003$ as the default value for our algorithm.

# %% [markdown]
# <a name="ex-4"></a>
# ### Exercise 4 - align_embeddings
#
# Implement `align_embeddings()`

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Use the 'compute_gradient()' function to get the gradient in each step</li>
#
# </ul>
# </p>

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def align_embeddings(X, Y, train_steps=100, learning_rate=0.0003, verbose=True, compute_loss=compute_loss, compute_gradient=compute_gradient):
    '''
    Inputs:
        X: a matrix of dimension (m,n) where the columns are the English embeddings.
        Y: a matrix of dimension (m,n) where the columns correspong to the French embeddings.
        train_steps: positive int - describes how many steps will gradient descent algorithm do.
        learning_rate: positive float - describes how big steps will  gradient descent algorithm do.
    Outputs:
        R: a matrix of dimension (n,n) - the projection matrix that minimizes the F norm ||X R -Y||^2
    '''
    np.random.seed(129)

    # the number of columns in X is the number of dimensions for a word vector (e.g. 300)
    # R is a square matrix with length equal to the number of dimensions in th  word embedding
    R = np.random.rand(X.shape[1], X.shape[1])

    for i in range(train_steps):
        if verbose and i % 25 == 0:
            print(f"loss at iteration {i} is: {compute_loss(X, Y, R):.4f}")
        ### START CODE HERE ###
        # use the function that you defined to compute the gradient
        gradient = compute_gradient(X, Y, R)

        # update R by subtracting the learning rate times gradient
        R -= learning_rate*gradient
        ### END CODE HERE ###
    return R

# %%
# UNQ_C6 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# Testing your implementation.
np.random.seed(129)
m = 10
n = 5
X = np.random.rand(m, n)
Y = np.random.rand(m, n) * .1
R = align_embeddings(X, Y)
# Out:
# loss at iteration 0 is: 3.7242
# loss at iteration 25 is: 3.6283
# loss at iteration 50 is: 3.5350
# loss at iteration 75 is: 3.4442

# %% [markdown]
# **Expected Output:**
# ```
# loss at iteration 0 is: 3.7242
# loss at iteration 25 is: 3.6283
# loss at iteration 50 is: 3.5350
# loss at iteration 75 is: 3.4442
# ```

# %%
# Test your function
w4_unittest.test_align_embeddings(align_embeddings)
# Out:
#  All tests passed

# %% [markdown]
# #### Calculate Transformation matrix R
#
# Using just the training set, find the transformation matrix $\mathbf{R}$ by calling the function `align_embeddings()`.
#
# **NOTE:** The code cell below will take a few minutes to fully execute (~3 mins)

# %%
# UNQ_C7 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything
R_train = align_embeddings(X_train, Y_train, train_steps=400, learning_rate=0.8)
# Out:
# loss at iteration 0 is: 963.0146
# loss at iteration 25 is: 97.8292
# loss at iteration 50 is: 26.8329
# loss at iteration 75 is: 9.7893
# loss at iteration 100 is: 4.3776
# loss at iteration 125 is: 2.3281
# loss at iteration 150 is: 1.4480
# loss at iteration 175 is: 1.0338
# loss at iteration 200 is: 0.8251
# loss at iteration 225 is: 0.7145
# loss at iteration 250 is: 0.6534
# loss at iteration 275 is: 0.6185
# loss at iteration 300 is: 0.5981
# loss at iteration 325 is: 0.5858
# loss at iteration 350 is: 0.5782
# loss at iteration 375 is: 0.5735

# %% [markdown]
# ##### Expected Output
#
# ```
# loss at iteration 0 is: 963.0146
# loss at iteration 25 is: 97.8292
# loss at iteration 50 is: 26.8329
# loss at iteration 75 is: 9.7893
# loss at iteration 100 is: 4.3776
# loss at iteration 125 is: 2.3281
# loss at iteration 150 is: 1.4480
# loss at iteration 175 is: 1.0338
# loss at iteration 200 is: 0.8251
# loss at iteration 225 is: 0.7145
# loss at iteration 250 is: 0.6534
# loss at iteration 275 is: 0.6185
# loss at iteration 300 is: 0.5981
# loss at iteration 325 is: 0.5858
# loss at iteration 350 is: 0.5782
# loss at iteration 375 is: 0.5735
# ```

# %% [markdown]
# <a name="2-2"></a>
# ### 2.2 - Testing the Translation
#
# #### k-Nearest Neighbors Algorithm
#
# [k-Nearest neighbors algorithm](https://en.wikipedia.org/wiki/K-nearest_neighbors_algorithm)
# * k-NN is a method which takes a vector as input and finds the other vectors in the dataset that are closest to it.
# * The 'k' is the number of "nearest neighbors" to find (e.g. k=2 finds the closest two neighbors).
#
# #### Searching for the Translation Embedding
# Since we're approximating the translation function from English to French embeddings by a linear transformation matrix $\mathbf{R}$, most of the time we won't get the exact embedding of a French word when we transform embedding $\mathbf{e}$ of some particular English word into the French embedding space.
# * This is where $k$-NN becomes really useful! By using $1$-NN with $\mathbf{eR}$ as input, we can search for an embedding $\mathbf{f}$ (as a row) in the matrix $\mathbf{Y}$ which is the closest to the transformed vector $\mathbf{eR}$

# %% [markdown]
# #### Cosine Similarity
# Cosine similarity between vectors $u$ and $v$ calculated as the cosine of the angle between them.
# The formula is
#
# $$\cos(u,v)=\frac{u\cdot v}{\left\|u\right\|\left\|v\right\|}$$
#
# * $\cos(u,v)$ = $1$ when $u$ and $v$ lie on the same line and have the same direction.
# * $\cos(u,v)$ is $-1$ when they have exactly opposite directions.
# * $\cos(u,v)$ is $0$ when the vectors are orthogonal (perpendicular) to each other.

# %% [markdown]
# #### Note: Distance and similarity are pretty much opposite things.
# * We can obtain distance metric from cosine similarity, but the cosine similarity can't be used directly as the distance metric.
# * When the cosine similarity increases (towards $1$), the "distance" between the two vectors decreases (towards $0$).
# * We can define the cosine distance between $u$ and $v$ as
# $$d_{\text{cos}}(u,v)=1-\cos(u,v)$$

# %% [markdown]
# <a name="ex-5"></a>
# ### Exercise 5 - nearest_neighbor
# Complete the function `nearest_neighbor()`
#
# Inputs:
# * Vector `v`,
# * A set of possible nearest neighbors `candidates`
# * `k` nearest neighbors to find.
# * The distance metric should be based on cosine similarity.
# * `cosine_similarity` function is already implemented and imported for you. It's arguments are two vectors and it returns the cosine of the angle between them.
# * Iterate over rows in `candidates`, and save the result of similarities between current row and vector `v` in a python list. Take care that similarities are in the same order as row vectors of `candidates`.
# * Now you can use [numpy argsort]( https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html#numpy.argsort) to sort the indices for the rows of `candidates`.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> numpy.argsort sorts values from most negative to most positive (smallest to largest) </li>
#     <li> The candidates that are nearest to 'v' should have the highest cosine similarity </li>
#     <li> To reverse the order of the result of numpy.argsort to get the element with highest cosine similarity as the first element of the array you can use tmp[::-1]. This reverses the order of an array. Then, you can extract the first k elements.</li>
# </ul>
# </p>

# %%
# UNQ_C8 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def nearest_neighbor(v, candidates, k=1, cosine_similarity=cosine_similarity):
    """
    Input:
      - v, the vector you are going find the nearest neighbor for
      - candidates: a set of vectors where we will find the neighbors
      - k: top k nearest neighbors to find
    Output:
      - k_idx: the indices of the top k closest vectors in sorted form
    """
    ### START CODE HERE ###
    similarity_l = []

    # for each candidate vector...
    for row in candidates:
        # get the cosine similarity
        cos_similarity = cosine_similarity(v, row)

        # append the similarity to the list
        similarity_l.append(cos_similarity)

    # sort the similarity list and get the indices of the sorted list    
    sorted_ids = np.argsort(similarity_l)
    
    # Reverse the order of the sorted_ids array
    sorted_ids = sorted_ids[::-1]
    
    # get the indices of the k most similar candidate vectors
    k_idx = sorted_ids[0:k]
    ### END CODE HERE ###
    return k_idx

# %%
# UNQ_C9 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# Test your implementation:
v = np.array([1, 0, 1])
candidates = np.array([[1, 0, 5], [-2, 5, 3], [2, 0, 1], [6, -9, 5], [9, 9, 9]])
print(candidates[nearest_neighbor(v, candidates, 3)])
# Out:
# [[2 0 1]
#  [1 0 5]
#  [9 9 9]]

# %% [markdown]
# **Expected Output**:
#
# `[[2 0 1]
#  [1 0 5]
#  [9 9 9]]`

# %%
# Test your function
w4_unittest.test_nearest_neighbor(nearest_neighbor)
# Out:
#  All tests passed

# %% [markdown]
# #### Test your Translation and Compute its Accuracy
#
# <a name="ex-6"></a>
# ### Exercise 6 - test_vocabulary
# Complete the function `test_vocabulary` which takes in English
# embedding matrix $X$, French embedding matrix $Y$ and the $R$
# matrix and returns the accuracy of translations from $X$ to $Y$ by $R$.
#
# * Iterate over transformed English word embeddings and check if the
# closest French word vector belongs to French word that is the actual
# translation.
# * Obtain an index of the closest French embedding by using
# `nearest_neighbor` (with argument `k=1`), and compare it to the index
# of the English embedding you have just transformed.
# * Keep track of the number of times you get the correct translation.
# * Calculate accuracy as $$\text{accuracy}=\frac{\#(\text{correct predictions})}{\#(\text{total predictions})}$$

# %%
# UNQ_C10 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def test_vocabulary(X, Y, R, nearest_neighbor=nearest_neighbor):
    '''
    Input:
        X: a matrix where the columns are the English embeddings.
        Y: a matrix where the columns correspong to the French embeddings.
        R: the transform matrix which translates word embeddings from
        English to French word vector space.
    Output:
        accuracy: for the English to French capitals
    '''

    ### START CODE HERE ###
    # The prediction is X times R
    print(f'X shape: {X.shape}')
    print(f'R shape: {R.shape}')
    print(f'Y shape: {Y.shape}')
    pred = X@R
    print(f'pred shape: {pred.shape}')
    print(len(pred))
    # initialize the number correct to zero
    num_correct = 0

    # loop through each row in pred (each transformed embedding)
    for i in range(len(pred)):
        # get the index of the nearest neighbor of pred at row 'i'; also pass in the candidates in Y
        pred_idx = nearest_neighbor(pred[i],Y, k=1)
        

        # if the index of the nearest neighbor equals the row of i... \
        if pred_idx == i :
            # increment the number correct by 1.
            num_correct += 1
            print(f'pred_idx value: {pred_idx}, index: {i}, number of correct values: {num_correct}, accumulated accuracy: {num_correct/len(pred):.4f}')

    # accuracy is the number correct divided by the number of rows in 'pred' (also number of rows in X)
    accuracy = num_correct/X.shape[0]

    ### END CODE HERE ###

    return accuracy

# %% [markdown]
# Let's see how is your translation mechanism working on the unseen data:

# %%
X_val, Y_val = get_matrices(en_fr_test, fr_embeddings_subset, en_embeddings_subset)

# %%
# UNQ_C11 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

acc = test_vocabulary(X_val, Y_val, R_train)  # this might take a minute or two
print(f"accuracy on test set is {acc:.3f}")
# Out:
# X shape: (1438, 300)
# R shape: (300, 300)
# Y shape: (1438, 300)
# pred shape: (1438, 300)
# 1438
# pred_idx value: [0], index: 0, number of correct values: 1                , accumulated accuracy: 0.0007
# pred_idx value: [2], index: 2, number of correct values: 2                , accumulated accuracy: 0.0014
# pred_idx value: [6], index: 6, number of correct values: 3                , accumulated accuracy: 0.0021
# pred_idx value: [8], index: 8, number of correct values: 4                , accumulated accuracy: 0.0028
# pred_idx value: [9], index: 9, number of correct values: 5                , accumulated accuracy: 0.0035
# pred_idx value: [10], index: 10, number of correct values: 6                , accumulated accuracy: 0.0042
# pred_idx value: [11], index: 11, number of correct values: 7                , accumulated accuracy: 0.0049
# pred_idx value: [12], index: 12, number of correct values: 8                , accumulated accuracy: 0.0056
# pred_idx value: [13], index: 13, number of correct values: 9                , accumulated accuracy: 0.0063
# pred_idx value: [14], index: 14, number of correct values: 10                , accumulated accuracy: 0.0070
# pred_idx value: [16], index: 16, number of correct values: 11                , accumulated accuracy: 0.0076
# pred_idx value: [19], index: 19, number of correct values: 12                , accumulated accuracy: 0.0083
# pred_idx value: [20], index: 20, number of correct values: 13                , accumulated accuracy: 0.0090
# pred_idx value: [22], index: 22, number of correct values: 14                , accumulated accuracy: 0.0097
# pred_idx value: [23], index: 23, number of correct values: 15                , accumulated accuracy: 0.0104
# pred_idx value: [24], index: 24, number of correct values: 16                , accumulated accuracy: 0.0111
# pred_idx value: [27], index: 27, number of correct values: 17                , accumulated accuracy: 0.0118
# pred_idx value: [28], index: 28, number of correct values: 18                , accumulated accuracy: 0.0125
# pred_idx value: [29], index: 29, number of correct values: 19                , accumulated accuracy: 0.0132
# pred_idx value: [33], index: 33, number of correct values: 20                , accumulated accuracy: 0.0139
# pred_idx value: [34], index: 34, number of correct values: 21                , accumulated accuracy: 0.0146
# pred_idx value: [35], index: 35, number of correct values: 22                , accumulated accuracy: 0.0153
# pred_idx value: [36], index: 36, number of correct values: 23                , accumulated accuracy: 0.0160
# pred_idx value: [37], index: 37, number of correct values: 24                , accumulated accuracy: 0.0167
# pred_idx value: [38], index: 38, number of correct values: 25                , accumulated accuracy: 0.0174
# pred_idx value: [39], index: 39, number of correct values: 26                , accumulated accuracy: 0.0181
# pred_idx value: [40], index: 40, number of correct values: 27                , accumulated accuracy: 0.0188
# pred_idx value: [41], index: 41, number of correct values: 28                , accumulated accuracy: 0.0195
# pred_idx value: [43], index: 43, number of correct values: 29                , accumulated accuracy: 0.0202
# pred_idx value: [45], index: 45, number of correct values: 30                , accumulated accuracy: 0.0209
# pred_idx value: [46], index: 46, number of correct values: 31                , accumulated accuracy: 0.0216
# pred_idx value: [47], index: 47, number of correct values: 32                , accumulated accuracy: 0.0223
# pred_idx value: [49], index: 49, number of correct values: 33                , accumulated accuracy: 0.0229
# pred_idx value: [50], index: 50, number of correct values: 34                , accumulated accuracy: 0.0236
# pred_idx value: [52], index: 52, number of correct values: 35                , accumulated accuracy: 0.0243
# pred_idx value: [56], index: 56, number of correct values: 36                , accumulated accuracy: 0.0250
# pred_idx value: [57], index: 57, number of correct values: 37                , accumulated accuracy: 0.0257
# pred_idx value: [59], index: 59, number of correct values: 38                , accumulated accuracy: 0.0264
# pred_idx value: [60], index: 60, number of correct values: 39                , accumulated accuracy: 0.0271
# pred_idx value: [61], index: 61, number of correct values: 40                , accumulated accuracy: 0.0278
# pred_idx value: [63], index: 63, number of correct values: 41                , accumulated accuracy: 0.0285
# pred_idx value: [67], index: 67, number of correct values: 42                , accumulated accuracy: 0.0292
# pred_idx value: [71], index: 71, number of correct values: 43                , accumulated accuracy: 0.0299
# pred_idx value: [72], index: 72, number of correct values: 44                , accumulated accuracy: 0.0306
# pred_idx value: [78], index: 78, number of correct values: 45                , accumulated accuracy: 0.0313
# pred_idx value: [79], index: 79, number of correct values: 46                , accumulated accuracy: 0.0320
# pred_idx value: [83], index: 83, number of correct values: 47                , accumulated accuracy: 0.0327
# pred_idx value: [88], index: 88, number of correct values: 48                , accumulated accuracy: 0.0334
# pred_idx value: [90], index: 90, number of correct values: 49                , accumulated accuracy: 0.0341
# pred_idx value: [91], index: 91, number of correct values: 50                , accumulated accuracy: 0.0348
# pred_idx value: [94], index: 94, number of correct values: 51                , accumulated accuracy: 0.0355
# pred_idx value: [97], index: 97, number of correct values: 52                , accumulated accuracy: 0.0362
# pred_idx value: [98], index: 98, number of correct values: 53                , accumulated accuracy: 0.0369
# pred_idx value: [100], index: 100, number of correct values: 54                , accumulated accuracy: 0.0376
# pred_idx value: [101], index: 101, number of correct values: 55                , accumulated accuracy: 0.0382
# pred_idx value: [107], index: 107, number of correct values: 56                , accumulated accuracy: 0.0389
# pred_idx value: [110], index: 110, number of correct values: 57                , accumulated accuracy: 0.0396
# pred_idx value: [111], index: 111, number of correct values: 58                , accumulated accuracy: 0.0403
# pred_idx value: [114], index: 114, number of correct values: 59                , accumulated accuracy: 0.0410
# pred_idx value: [115], index: 115, number of correct values: 60                , accumulated accuracy: 0.0417
# pred_idx value: [117], index: 117, number of correct values: 61                , accumulated accuracy: 0.0424
# pred_idx value: [118], index: 118, number of correct values: 62                , accumulated accuracy: 0.0431
# pred_idx value: [121], index: 121, number of correct values: 63                , accumulated accuracy: 0.0438
# pred_idx value: [123], index: 123, number of correct values: 64                , accumulated accuracy: 0.0445
# pred_idx value: [127], index: 127, number of correct values: 65                , accumulated accuracy: 0.0452
# pred_idx value: [131], index: 131, number of correct values: 66                , accumulated accuracy: 0.0459
# pred_idx value: [136], index: 136, number of correct values: 67                , accumulated accuracy: 0.0466
# pred_idx value: [137], index: 137, number of correct values: 68                , accumulated accuracy: 0.0473
# pred_idx value: [138], index: 138, number of correct values: 69                , accumulated accuracy: 0.0480
# pred_idx value: [139], index: 139, number of correct values: 70                , accumulated accuracy: 0.0487
# pred_idx value: [140], index: 140, number of correct values: 71                , accumulated accuracy: 0.0494
# pred_idx value: [141], index: 141, number of correct values: 72                , accumulated accuracy: 0.0501
# pred_idx value: [142], index: 142, number of correct values: 73                , accumulated accuracy: 0.0508
# pred_idx value: [143], index: 143, number of correct values: 74                , accumulated accuracy: 0.0515
# pred_idx value: [147], index: 147, number of correct values: 75                , accumulated accuracy: 0.0522
# pred_idx value: [148], index: 148, number of correct values: 76                , accumulated accuracy: 0.0529
# pred_idx value: [149], index: 149, number of correct values: 77                , accumulated accuracy: 0.0535
# pred_idx value: [151], index: 151, number of correct values: 78                , accumulated accuracy: 0.0542
# pred_idx value: [161], index: 161, number of correct values: 79                , accumulated accuracy: 0.0549
# pred_idx value: [162], index: 162, number of correct values: 80                , accumulated accuracy: 0.0556
# pred_idx value: [165], index: 165, number of correct values: 81                , accumulated accuracy: 0.0563
# pred_idx value: [167], index: 167, number of correct values: 82                , accumulated accuracy: 0.0570
# pred_idx value: [169], index: 169, number of correct values: 83                , accumulated accuracy: 0.0577
# pred_idx value: [170], index: 170, number of correct values: 84                , accumulated accuracy: 0.0584
# pred_idx value: [172], index: 172, number of correct values: 85                , accumulated accuracy: 0.0591
# pred_idx value: [173], index: 173, number of correct values: 86                , accumulated accuracy: 0.0598
# pred_idx value: [174], index: 174, number of correct values: 87                , accumulated accuracy: 0.0605
# pred_idx value: [175], index: 175, number of correct values: 88                , accumulated accuracy: 0.0612
# pred_idx value: [176], index: 176, number of correct values: 89                , accumulated accuracy: 0.0619
# pred_idx value: [180], index: 180, number of correct values: 90                , accumulated accuracy: 0.0626
# pred_idx value: [181], index: 181, number of correct values: 91                , accumulated accuracy: 0.0633
# pred_idx value: [182], index: 182, number of correct values: 92                , accumulated accuracy: 0.0640
# pred_idx value: [185], index: 185, number of correct values: 93                , accumulated accuracy: 0.0647
# pred_idx value: [186], index: 186, number of correct values: 94                , accumulated accuracy: 0.0654
# pred_idx value: [187], index: 187, number of correct values: 95                , accumulated accuracy: 0.0661
# pred_idx value: [189], index: 189, number of correct values: 96                , accumulated accuracy: 0.0668
# pred_idx value: [190], index: 190, number of correct values: 97                , accumulated accuracy: 0.0675
# pred_idx value: [191], index: 191, number of correct values: 98                , accumulated accuracy: 0.0682
# pred_idx value: [192], index: 192, number of correct values: 99                , accumulated accuracy: 0.0688
# pred_idx value: [193], index: 193, number of correct values: 100                , accumulated accuracy: 0.0695
# pred_idx value: [194], index: 194, number of correct values: 101                , accumulated accuracy: 0.0702
# pred_idx value: [196], index: 196, number of correct values: 102                , accumulated accuracy: 0.0709
# pred_idx value: [198], index: 198, number of correct values: 103                , accumulated accuracy: 0.0716
# pred_idx value: [199], index: 199, number of correct values: 104                , accumulated accuracy: 0.0723
# pred_idx value: [200], index: 200, number of correct values: 105                , accumulated accuracy: 0.0730
# pred_idx value: [202], index: 202, number of correct values: 106                , accumulated accuracy: 0.0737
# pred_idx value: [204], index: 204, number of correct values: 107                , accumulated accuracy: 0.0744
# pred_idx value: [205], index: 205, number of correct values: 108                , accumulated accuracy: 0.0751
# pred_idx value: [206], index: 206, number of correct values: 109                , accumulated accuracy: 0.0758
# pred_idx value: [212], index: 212, number of correct values: 110                , accumulated accuracy: 0.0765
# pred_idx value: [213], index: 213, number of correct values: 111                , accumulated accuracy: 0.0772
# pred_idx value: [214], index: 214, number of correct values: 112                , accumulated accuracy: 0.0779
# pred_idx value: [217], index: 217, number of correct values: 113                , accumulated accuracy: 0.0786
# pred_idx value: [218], index: 218, number of correct values: 114                , accumulated accuracy: 0.0793
# pred_idx value: [220], index: 220, number of correct values: 115                , accumulated accuracy: 0.0800
# pred_idx value: [224], index: 224, number of correct values: 116                , accumulated accuracy: 0.0807
# pred_idx value: [226], index: 226, number of correct values: 117                , accumulated accuracy: 0.0814
# pred_idx value: [227], index: 227, number of correct values: 118                , accumulated accuracy: 0.0821
# pred_idx value: [228], index: 228, number of correct values: 119                , accumulated accuracy: 0.0828
# pred_idx value: [229], index: 229, number of correct values: 120                , accumulated accuracy: 0.0834
# pred_idx value: [231], index: 231, number of correct values: 121                , accumulated accuracy: 0.0841
# pred_idx value: [232], index: 232, number of correct values: 122                , accumulated accuracy: 0.0848
# pred_idx value: [233], index: 233, number of correct values: 123                , accumulated accuracy: 0.0855
# pred_idx value: [234], index: 234, number of correct values: 124                , accumulated accuracy: 0.0862
# pred_idx value: [235], index: 235, number of correct values: 125                , accumulated accuracy: 0.0869
# pred_idx value: [239], index: 239, number of correct values: 126                , accumulated accuracy: 0.0876
# pred_idx value: [240], index: 240, number of correct values: 127                , accumulated accuracy: 0.0883
# pred_idx value: [242], index: 242, number of correct values: 128                , accumulated accuracy: 0.0890
# pred_idx value: [243], index: 243, number of correct values: 129                , accumulated accuracy: 0.0897
# pred_idx value: [244], index: 244, number of correct values: 130                , accumulated accuracy: 0.0904
# pred_idx value: [245], index: 245, number of correct values: 131                , accumulated accuracy: 0.0911
# pred_idx value: [246], index: 246, number of correct values: 132                , accumulated accuracy: 0.0918
# pred_idx value: [247], index: 247, number of correct values: 133                , accumulated accuracy: 0.0925
# pred_idx value: [249], index: 249, number of correct values: 134                , accumulated accuracy: 0.0932
# pred_idx value: [251], index: 251, number of correct values: 135                , accumulated accuracy: 0.0939
# pred_idx value: [252], index: 252, number of correct values: 136                , accumulated accuracy: 0.0946
# pred_idx value: [253], index: 253, number of correct values: 137                , accumulated accuracy: 0.0953
# pred_idx value: [255], index: 255, number of correct values: 138                , accumulated accuracy: 0.0960
# pred_idx value: [257], index: 257, number of correct values: 139                , accumulated accuracy: 0.0967
# pred_idx value: [258], index: 258, number of correct values: 140                , accumulated accuracy: 0.0974
# pred_idx value: [262], index: 262, number of correct values: 141                , accumulated accuracy: 0.0981
# pred_idx value: [263], index: 263, number of correct values: 142                , accumulated accuracy: 0.0987
# pred_idx value: [264], index: 264, number of correct values: 143                , accumulated accuracy: 0.0994
# pred_idx value: [265], index: 265, number of correct values: 144                , accumulated accuracy: 0.1001
# pred_idx value: [267], index: 267, number of correct values: 145                , accumulated accuracy: 0.1008
# pred_idx value: [268], index: 268, number of correct values: 146                , accumulated accuracy: 0.1015
# pred_idx value: [270], index: 270, number of correct values: 147                , accumulated accuracy: 0.1022
# pred_idx value: [273], index: 273, number of correct values: 148                , accumulated accuracy: 0.1029
# pred_idx value: [274], index: 274, number of correct values: 149                , accumulated accuracy: 0.1036
# pred_idx value: [275], index: 275, number of correct values: 150                , accumulated accuracy: 0.1043
# pred_idx value: [276], index: 276, number of correct values: 151                , accumulated accuracy: 0.1050
# pred_idx value: [279], index: 279, number of correct values: 152                , accumulated accuracy: 0.1057
# pred_idx value: [280], index: 280, number of correct values: 153                , accumulated accuracy: 0.1064
# pred_idx value: [282], index: 282, number of correct values: 154                , accumulated accuracy: 0.1071
# pred_idx value: [283], index: 283, number of correct values: 155                , accumulated accuracy: 0.1078
# pred_idx value: [285], index: 285, number of correct values: 156                , accumulated accuracy: 0.1085
# pred_idx value: [286], index: 286, number of correct values: 157                , accumulated accuracy: 0.1092
# pred_idx value: [287], index: 287, number of correct values: 158                , accumulated accuracy: 0.1099
# pred_idx value: [290], index: 290, number of correct values: 159                , accumulated accuracy: 0.1106
# pred_idx value: [291], index: 291, number of correct values: 160                , accumulated accuracy: 0.1113
# pred_idx value: [292], index: 292, number of correct values: 161                , accumulated accuracy: 0.1120
# pred_idx value: [293], index: 293, number of correct values: 162                , accumulated accuracy: 0.1127
# pred_idx value: [294], index: 294, number of correct values: 163                , accumulated accuracy: 0.1134
# pred_idx value: [296], index: 296, number of correct values: 164                , accumulated accuracy: 0.1140
# pred_idx value: [298], index: 298, number of correct values: 165                , accumulated accuracy: 0.1147
# pred_idx value: [299], index: 299, number of correct values: 166                , accumulated accuracy: 0.1154
# pred_idx value: [300], index: 300, number of correct values: 167                , accumulated accuracy: 0.1161
# pred_idx value: [302], index: 302, number of correct values: 168                , accumulated accuracy: 0.1168
# pred_idx value: [304], index: 304, number of correct values: 169                , accumulated accuracy: 0.1175
# pred_idx value: [306], index: 306, number of correct values: 170                , accumulated accuracy: 0.1182
# pred_idx value: [308], index: 308, number of correct values: 171                , accumulated accuracy: 0.1189
# pred_idx value: [309], index: 309, number of correct values: 172                , accumulated accuracy: 0.1196
# pred_idx value: [311], index: 311, number of correct values: 173                , accumulated accuracy: 0.1203
# pred_idx value: [318], index: 318, number of correct values: 174                , accumulated accuracy: 0.1210
# pred_idx value: [321], index: 321, number of correct values: 175                , accumulated accuracy: 0.1217
# pred_idx value: [322], index: 322, number of correct values: 176                , accumulated accuracy: 0.1224
# pred_idx value: [324], index: 324, number of correct values: 177                , accumulated accuracy: 0.1231
# pred_idx value: [327], index: 327, number of correct values: 178                , accumulated accuracy: 0.1238
# pred_idx value: [328], index: 328, number of correct values: 179                , accumulated accuracy: 0.1245
# pred_idx value: [329], index: 329, number of correct values: 180                , accumulated accuracy: 0.1252
# pred_idx value: [331], index: 331, number of correct values: 181                , accumulated accuracy: 0.1259
# pred_idx value: [332], index: 332, number of correct values: 182                , accumulated accuracy: 0.1266
# pred_idx value: [334], index: 334, number of correct values: 183                , accumulated accuracy: 0.1273
# pred_idx value: [335], index: 335, number of correct values: 184                , accumulated accuracy: 0.1280
# pred_idx value: [336], index: 336, number of correct values: 185                , accumulated accuracy: 0.1287
# pred_idx value: [339], index: 339, number of correct values: 186                , accumulated accuracy: 0.1293
# pred_idx value: [340], index: 340, number of correct values: 187                , accumulated accuracy: 0.1300
# pred_idx value: [341], index: 341, number of correct values: 188                , accumulated accuracy: 0.1307
# pred_idx value: [345], index: 345, number of correct values: 189                , accumulated accuracy: 0.1314
# pred_idx value: [347], index: 347, number of correct values: 190                , accumulated accuracy: 0.1321
# pred_idx value: [350], index: 350, number of correct values: 191                , accumulated accuracy: 0.1328
# pred_idx value: [351], index: 351, number of correct values: 192                , accumulated accuracy: 0.1335
# pred_idx value: [353], index: 353, number of correct values: 193                , accumulated accuracy: 0.1342
# pred_idx value: [357], index: 357, number of correct values: 194                , accumulated accuracy: 0.1349
# pred_idx value: [358], index: 358, number of correct values: 195                , accumulated accuracy: 0.1356
# pred_idx value: [360], index: 360, number of correct values: 196                , accumulated accuracy: 0.1363
# pred_idx value: [362], index: 362, number of correct values: 197                , accumulated accuracy: 0.1370
# pred_idx value: [364], index: 364, number of correct values: 198                , accumulated accuracy: 0.1377
# pred_idx value: [365], index: 365, number of correct values: 199                , accumulated accuracy: 0.1384
# pred_idx value: [366], index: 366, number of correct values: 200                , accumulated accuracy: 0.1391
# pred_idx value: [367], index: 367, number of correct values: 201                , accumulated accuracy: 0.1398
# pred_idx value: [369], index: 369, number of correct values: 202                , accumulated accuracy: 0.1405
# pred_idx value: [370], index: 370, number of correct values: 203                , accumulated accuracy: 0.1412
# pred_idx value: [371], index: 371, number of correct values: 204                , accumulated accuracy: 0.1419
# pred_idx value: [372], index: 372, number of correct values: 205                , accumulated accuracy: 0.1426
# pred_idx value: [373], index: 373, number of correct values: 206                , accumulated accuracy: 0.1433
# pred_idx value: [377], index: 377, number of correct values: 207                , accumulated accuracy: 0.1439
# pred_idx value: [378], index: 378, number of correct values: 208                , accumulated accuracy: 0.1446
# pred_idx value: [380], index: 380, number of correct values: 209                , accumulated accuracy: 0.1453
# pred_idx value: [381], index: 381, number of correct values: 210                , accumulated accuracy: 0.1460
# pred_idx value: [384], index: 384, number of correct values: 211                , accumulated accuracy: 0.1467
# pred_idx value: [385], index: 385, number of correct values: 212                , accumulated accuracy: 0.1474
# pred_idx value: [386], index: 386, number of correct values: 213                , accumulated accuracy: 0.1481
# pred_idx value: [387], index: 387, number of correct values: 214                , accumulated accuracy: 0.1488
# pred_idx value: [388], index: 388, number of correct values: 215                , accumulated accuracy: 0.1495
# pred_idx value: [389], index: 389, number of correct values: 216                , accumulated accuracy: 0.1502
# pred_idx value: [392], index: 392, number of correct values: 217                , accumulated accuracy: 0.1509
# pred_idx value: [393], index: 393, number of correct values: 218                , accumulated accuracy: 0.1516
# pred_idx value: [394], index: 394, number of correct values: 219                , accumulated accuracy: 0.1523
# pred_idx value: [396], index: 396, number of correct values: 220                , accumulated accuracy: 0.1530
# pred_idx value: [397], index: 397, number of correct values: 221                , accumulated accuracy: 0.1537
# pred_idx value: [398], index: 398, number of correct values: 222                , accumulated accuracy: 0.1544
# pred_idx value: [399], index: 399, number of correct values: 223                , accumulated accuracy: 0.1551
# pred_idx value: [400], index: 400, number of correct values: 224                , accumulated accuracy: 0.1558
# pred_idx value: [402], index: 402, number of correct values: 225                , accumulated accuracy: 0.1565
# pred_idx value: [403], index: 403, number of correct values: 226                , accumulated accuracy: 0.1572
# pred_idx value: [405], index: 405, number of correct values: 227                , accumulated accuracy: 0.1579
# pred_idx value: [406], index: 406, number of correct values: 228                , accumulated accuracy: 0.1586
# pred_idx value: [408], index: 408, number of correct values: 229                , accumulated accuracy: 0.1592
# pred_idx value: [409], index: 409, number of correct values: 230                , accumulated accuracy: 0.1599
# pred_idx value: [410], index: 410, number of correct values: 231                , accumulated accuracy: 0.1606
# pred_idx value: [411], index: 411, number of correct values: 232                , accumulated accuracy: 0.1613
# pred_idx value: [412], index: 412, number of correct values: 233                , accumulated accuracy: 0.1620
# pred_idx value: [414], index: 414, number of correct values: 234                , accumulated accuracy: 0.1627
# pred_idx value: [415], index: 415, number of correct values: 235                , accumulated accuracy: 0.1634
# pred_idx value: [416], index: 416, number of correct values: 236                , accumulated accuracy: 0.1641
# pred_idx value: [417], index: 417, number of correct values: 237                , accumulated accuracy: 0.1648
# pred_idx value: [420], index: 420, number of correct values: 238                , accumulated accuracy: 0.1655
# pred_idx value: [421], index: 421, number of correct values: 239                , accumulated accuracy: 0.1662
# pred_idx value: [425], index: 425, number of correct values: 240                , accumulated accuracy: 0.1669
# pred_idx value: [426], index: 426, number of correct values: 241                , accumulated accuracy: 0.1676
# pred_idx value: [428], index: 428, number of correct values: 242                , accumulated accuracy: 0.1683
# pred_idx value: [429], index: 429, number of correct values: 243                , accumulated accuracy: 0.1690
# pred_idx value: [431], index: 431, number of correct values: 244                , accumulated accuracy: 0.1697
# pred_idx value: [434], index: 434, number of correct values: 245                , accumulated accuracy: 0.1704
# pred_idx value: [435], index: 435, number of correct values: 246                , accumulated accuracy: 0.1711
# pred_idx value: [436], index: 436, number of correct values: 247                , accumulated accuracy: 0.1718
# pred_idx value: [438], index: 438, number of correct values: 248                , accumulated accuracy: 0.1725
# pred_idx value: [439], index: 439, number of correct values: 249                , accumulated accuracy: 0.1732
# pred_idx value: [440], index: 440, number of correct values: 250                , accumulated accuracy: 0.1739
# pred_idx value: [441], index: 441, number of correct values: 251                , accumulated accuracy: 0.1745
# pred_idx value: [442], index: 442, number of correct values: 252                , accumulated accuracy: 0.1752
# pred_idx value: [443], index: 443, number of correct values: 253                , accumulated accuracy: 0.1759
# pred_idx value: [444], index: 444, number of correct values: 254                , accumulated accuracy: 0.1766
# pred_idx value: [445], index: 445, number of correct values: 255                , accumulated accuracy: 0.1773
# pred_idx value: [446], index: 446, number of correct values: 256                , accumulated accuracy: 0.1780
# pred_idx value: [447], index: 447, number of correct values: 257                , accumulated accuracy: 0.1787
# pred_idx value: [448], index: 448, number of correct values: 258                , accumulated accuracy: 0.1794
# pred_idx value: [449], index: 449, number of correct values: 259                , accumulated accuracy: 0.1801
# pred_idx value: [456], index: 456, number of correct values: 260                , accumulated accuracy: 0.1808
# pred_idx value: [457], index: 457, number of correct values: 261                , accumulated accuracy: 0.1815
# pred_idx value: [458], index: 458, number of correct values: 262                , accumulated accuracy: 0.1822
# pred_idx value: [460], index: 460, number of correct values: 263                , accumulated accuracy: 0.1829
# pred_idx value: [462], index: 462, number of correct values: 264                , accumulated accuracy: 0.1836
# pred_idx value: [466], index: 466, number of correct values: 265                , accumulated accuracy: 0.1843
# pred_idx value: [467], index: 467, number of correct values: 266                , accumulated accuracy: 0.1850
# pred_idx value: [468], index: 468, number of correct values: 267                , accumulated accuracy: 0.1857
# pred_idx value: [470], index: 470, number of correct values: 268                , accumulated accuracy: 0.1864
# pred_idx value: [471], index: 471, number of correct values: 269                , accumulated accuracy: 0.1871
# pred_idx value: [473], index: 473, number of correct values: 270                , accumulated accuracy: 0.1878
# pred_idx value: [474], index: 474, number of correct values: 271                , accumulated accuracy: 0.1885
# pred_idx value: [475], index: 475, number of correct values: 272                , accumulated accuracy: 0.1892
# pred_idx value: [476], index: 476, number of correct values: 273                , accumulated accuracy: 0.1898
# pred_idx value: [477], index: 477, number of correct values: 274                , accumulated accuracy: 0.1905
# pred_idx value: [481], index: 481, number of correct values: 275                , accumulated accuracy: 0.1912
# pred_idx value: [482], index: 482, number of correct values: 276                , accumulated accuracy: 0.1919
# pred_idx value: [483], index: 483, number of correct values: 277                , accumulated accuracy: 0.1926
# pred_idx value: [485], index: 485, number of correct values: 278                , accumulated accuracy: 0.1933
# pred_idx value: [486], index: 486, number of correct values: 279                , accumulated accuracy: 0.1940
# pred_idx value: [487], index: 487, number of correct values: 280                , accumulated accuracy: 0.1947
# pred_idx value: [489], index: 489, number of correct values: 281                , accumulated accuracy: 0.1954
# pred_idx value: [496], index: 496, number of correct values: 282                , accumulated accuracy: 0.1961
# pred_idx value: [497], index: 497, number of correct values: 283                , accumulated accuracy: 0.1968
# pred_idx value: [500], index: 500, number of correct values: 284                , accumulated accuracy: 0.1975
# pred_idx value: [502], index: 502, number of correct values: 285                , accumulated accuracy: 0.1982
# pred_idx value: [504], index: 504, number of correct values: 286                , accumulated accuracy: 0.1989
# pred_idx value: [506], index: 506, number of correct values: 287                , accumulated accuracy: 0.1996
# pred_idx value: [507], index: 507, number of correct values: 288                , accumulated accuracy: 0.2003
# pred_idx value: [509], index: 509, number of correct values: 289                , accumulated accuracy: 0.2010
# pred_idx value: [510], index: 510, number of correct values: 290                , accumulated accuracy: 0.2017
# pred_idx value: [511], index: 511, number of correct values: 291                , accumulated accuracy: 0.2024
# pred_idx value: [512], index: 512, number of correct values: 292                , accumulated accuracy: 0.2031
# pred_idx value: [515], index: 515, number of correct values: 293                , accumulated accuracy: 0.2038
# pred_idx value: [516], index: 516, number of correct values: 294                , accumulated accuracy: 0.2045
# pred_idx value: [517], index: 517, number of correct values: 295                , accumulated accuracy: 0.2051
# pred_idx value: [519], index: 519, number of correct values: 296                , accumulated accuracy: 0.2058
# pred_idx value: [520], index: 520, number of correct values: 297                , accumulated accuracy: 0.2065
# pred_idx value: [521], index: 521, number of correct values: 298                , accumulated accuracy: 0.2072
# pred_idx value: [522], index: 522, number of correct values: 299                , accumulated accuracy: 0.2079
# pred_idx value: [523], index: 523, number of correct values: 300                , accumulated accuracy: 0.2086
# pred_idx value: [526], index: 526, number of correct values: 301                , accumulated accuracy: 0.2093
# pred_idx value: [529], index: 529, number of correct values: 302                , accumulated accuracy: 0.2100
# pred_idx value: [531], index: 531, number of correct values: 303                , accumulated accuracy: 0.2107
# pred_idx value: [533], index: 533, number of correct values: 304                , accumulated accuracy: 0.2114
# pred_idx value: [534], index: 534, number of correct values: 305                , accumulated accuracy: 0.2121
# pred_idx value: [535], index: 535, number of correct values: 306                , accumulated accuracy: 0.2128
# pred_idx value: [536], index: 536, number of correct values: 307                , accumulated accuracy: 0.2135
# pred_idx value: [538], index: 538, number of correct values: 308                , accumulated accuracy: 0.2142
# pred_idx value: [540], index: 540, number of correct values: 309                , accumulated accuracy: 0.2149
# pred_idx value: [543], index: 543, number of correct values: 310                , accumulated accuracy: 0.2156
# pred_idx value: [544], index: 544, number of correct values: 311                , accumulated accuracy: 0.2163
# pred_idx value: [545], index: 545, number of correct values: 312                , accumulated accuracy: 0.2170
# pred_idx value: [547], index: 547, number of correct values: 313                , accumulated accuracy: 0.2177
# pred_idx value: [548], index: 548, number of correct values: 314                , accumulated accuracy: 0.2184
# pred_idx value: [550], index: 550, number of correct values: 315                , accumulated accuracy: 0.2191
# pred_idx value: [552], index: 552, number of correct values: 316                , accumulated accuracy: 0.2197
# pred_idx value: [553], index: 553, number of correct values: 317                , accumulated accuracy: 0.2204
# pred_idx value: [559], index: 559, number of correct values: 318                , accumulated accuracy: 0.2211
# pred_idx value: [560], index: 560, number of correct values: 319                , accumulated accuracy: 0.2218
# pred_idx value: [562], index: 562, number of correct values: 320                , accumulated accuracy: 0.2225
# pred_idx value: [566], index: 566, number of correct values: 321                , accumulated accuracy: 0.2232
# pred_idx value: [568], index: 568, number of correct values: 322                , accumulated accuracy: 0.2239
# pred_idx value: [570], index: 570, number of correct values: 323                , accumulated accuracy: 0.2246
# pred_idx value: [574], index: 574, number of correct values: 324                , accumulated accuracy: 0.2253
# pred_idx value: [576], index: 576, number of correct values: 325                , accumulated accuracy: 0.2260
# pred_idx value: [578], index: 578, number of correct values: 326                , accumulated accuracy: 0.2267
# pred_idx value: [581], index: 581, number of correct values: 327                , accumulated accuracy: 0.2274
# pred_idx value: [582], index: 582, number of correct values: 328                , accumulated accuracy: 0.2281
# pred_idx value: [584], index: 584, number of correct values: 329                , accumulated accuracy: 0.2288
# pred_idx value: [586], index: 586, number of correct values: 330                , accumulated accuracy: 0.2295
# pred_idx value: [588], index: 588, number of correct values: 331                , accumulated accuracy: 0.2302
# pred_idx value: [591], index: 591, number of correct values: 332                , accumulated accuracy: 0.2309
# pred_idx value: [593], index: 593, number of correct values: 333                , accumulated accuracy: 0.2316
# pred_idx value: [595], index: 595, number of correct values: 334                , accumulated accuracy: 0.2323
# pred_idx value: [597], index: 597, number of correct values: 335                , accumulated accuracy: 0.2330
# pred_idx value: [599], index: 599, number of correct values: 336                , accumulated accuracy: 0.2337
# pred_idx value: [600], index: 600, number of correct values: 337                , accumulated accuracy: 0.2344
# pred_idx value: [605], index: 605, number of correct values: 338                , accumulated accuracy: 0.2350
# pred_idx value: [608], index: 608, number of correct values: 339                , accumulated accuracy: 0.2357
# pred_idx value: [609], index: 609, number of correct values: 340                , accumulated accuracy: 0.2364
# pred_idx value: [610], index: 610, number of correct values: 341                , accumulated accuracy: 0.2371
# pred_idx value: [611], index: 611, number of correct values: 342                , accumulated accuracy: 0.2378
# pred_idx value: [613], index: 613, number of correct values: 343                , accumulated accuracy: 0.2385
# pred_idx value: [614], index: 614, number of correct values: 344                , accumulated accuracy: 0.2392
# pred_idx value: [616], index: 616, number of correct values: 345                , accumulated accuracy: 0.2399
# pred_idx value: [621], index: 621, number of correct values: 346                , accumulated accuracy: 0.2406
# pred_idx value: [622], index: 622, number of correct values: 347                , accumulated accuracy: 0.2413
# pred_idx value: [624], index: 624, number of correct values: 348                , accumulated accuracy: 0.2420
# pred_idx value: [628], index: 628, number of correct values: 349                , accumulated accuracy: 0.2427
# pred_idx value: [629], index: 629, number of correct values: 350                , accumulated accuracy: 0.2434
# pred_idx value: [630], index: 630, number of correct values: 351                , accumulated accuracy: 0.2441
# pred_idx value: [631], index: 631, number of correct values: 352                , accumulated accuracy: 0.2448
# pred_idx value: [636], index: 636, number of correct values: 353                , accumulated accuracy: 0.2455
# pred_idx value: [637], index: 637, number of correct values: 354                , accumulated accuracy: 0.2462
# pred_idx value: [638], index: 638, number of correct values: 355                , accumulated accuracy: 0.2469
# pred_idx value: [641], index: 641, number of correct values: 356                , accumulated accuracy: 0.2476
# pred_idx value: [642], index: 642, number of correct values: 357                , accumulated accuracy: 0.2483
# pred_idx value: [645], index: 645, number of correct values: 358                , accumulated accuracy: 0.2490
# pred_idx value: [648], index: 648, number of correct values: 359                , accumulated accuracy: 0.2497
# pred_idx value: [650], index: 650, number of correct values: 360                , accumulated accuracy: 0.2503
# pred_idx value: [651], index: 651, number of correct values: 361                , accumulated accuracy: 0.2510
# pred_idx value: [654], index: 654, number of correct values: 362                , accumulated accuracy: 0.2517
# pred_idx value: [655], index: 655, number of correct values: 363                , accumulated accuracy: 0.2524
# pred_idx value: [656], index: 656, number of correct values: 364                , accumulated accuracy: 0.2531
# pred_idx value: [658], index: 658, number of correct values: 365                , accumulated accuracy: 0.2538
# pred_idx value: [660], index: 660, number of correct values: 366                , accumulated accuracy: 0.2545
# pred_idx value: [661], index: 661, number of correct values: 367                , accumulated accuracy: 0.2552
# pred_idx value: [662], index: 662, number of correct values: 368                , accumulated accuracy: 0.2559
# pred_idx value: [663], index: 663, number of correct values: 369                , accumulated accuracy: 0.2566
# pred_idx value: [664], index: 664, number of correct values: 370                , accumulated accuracy: 0.2573
# pred_idx value: [665], index: 665, number of correct values: 371                , accumulated accuracy: 0.2580
# pred_idx value: [667], index: 667, number of correct values: 372                , accumulated accuracy: 0.2587
# pred_idx value: [669], index: 669, number of correct values: 373                , accumulated accuracy: 0.2594
# pred_idx value: [671], index: 671, number of correct values: 374                , accumulated accuracy: 0.2601
# pred_idx value: [674], index: 674, number of correct values: 375                , accumulated accuracy: 0.2608
# pred_idx value: [675], index: 675, number of correct values: 376                , accumulated accuracy: 0.2615
# pred_idx value: [680], index: 680, number of correct values: 377                , accumulated accuracy: 0.2622
# pred_idx value: [681], index: 681, number of correct values: 378                , accumulated accuracy: 0.2629
# pred_idx value: [682], index: 682, number of correct values: 379                , accumulated accuracy: 0.2636
# pred_idx value: [683], index: 683, number of correct values: 380                , accumulated accuracy: 0.2643
# pred_idx value: [686], index: 686, number of correct values: 381                , accumulated accuracy: 0.2650
# pred_idx value: [688], index: 688, number of correct values: 382                , accumulated accuracy: 0.2656
# pred_idx value: [689], index: 689, number of correct values: 383                , accumulated accuracy: 0.2663
# pred_idx value: [693], index: 693, number of correct values: 384                , accumulated accuracy: 0.2670
# pred_idx value: [694], index: 694, number of correct values: 385                , accumulated accuracy: 0.2677
# pred_idx value: [695], index: 695, number of correct values: 386                , accumulated accuracy: 0.2684
# pred_idx value: [696], index: 696, number of correct values: 387                , accumulated accuracy: 0.2691
# pred_idx value: [697], index: 697, number of correct values: 388                , accumulated accuracy: 0.2698
# pred_idx value: [700], index: 700, number of correct values: 389                , accumulated accuracy: 0.2705
# pred_idx value: [701], index: 701, number of correct values: 390                , accumulated accuracy: 0.2712
# pred_idx value: [703], index: 703, number of correct values: 391                , accumulated accuracy: 0.2719
# pred_idx value: [704], index: 704, number of correct values: 392                , accumulated accuracy: 0.2726
# pred_idx value: [705], index: 705, number of correct values: 393                , accumulated accuracy: 0.2733
# pred_idx value: [706], index: 706, number of correct values: 394                , accumulated accuracy: 0.2740
# pred_idx value: [708], index: 708, number of correct values: 395                , accumulated accuracy: 0.2747
# pred_idx value: [710], index: 710, number of correct values: 396                , accumulated accuracy: 0.2754
# pred_idx value: [712], index: 712, number of correct values: 397                , accumulated accuracy: 0.2761
# pred_idx value: [715], index: 715, number of correct values: 398                , accumulated accuracy: 0.2768
# pred_idx value: [717], index: 717, number of correct values: 399                , accumulated accuracy: 0.2775
# pred_idx value: [718], index: 718, number of correct values: 400                , accumulated accuracy: 0.2782
# pred_idx value: [720], index: 720, number of correct values: 401                , accumulated accuracy: 0.2789
# pred_idx value: [721], index: 721, number of correct values: 402                , accumulated accuracy: 0.2796
# pred_idx value: [726], index: 726, number of correct values: 403                , accumulated accuracy: 0.2803
# pred_idx value: [728], index: 728, number of correct values: 404                , accumulated accuracy: 0.2809
# pred_idx value: [730], index: 730, number of correct values: 405                , accumulated accuracy: 0.2816
# pred_idx value: [731], index: 731, number of correct values: 406                , accumulated accuracy: 0.2823
# pred_idx value: [737], index: 737, number of correct values: 407                , accumulated accuracy: 0.2830
# pred_idx value: [740], index: 740, number of correct values: 408                , accumulated accuracy: 0.2837
# pred_idx value: [742], index: 742, number of correct values: 409                , accumulated accuracy: 0.2844
# pred_idx value: [743], index: 743, number of correct values: 410                , accumulated accuracy: 0.2851
# pred_idx value: [745], index: 745, number of correct values: 411                , accumulated accuracy: 0.2858
# pred_idx value: [746], index: 746, number of correct values: 412                , accumulated accuracy: 0.2865
# pred_idx value: [747], index: 747, number of correct values: 413                , accumulated accuracy: 0.2872
# pred_idx value: [748], index: 748, number of correct values: 414                , accumulated accuracy: 0.2879
# pred_idx value: [749], index: 749, number of correct values: 415                , accumulated accuracy: 0.2886
# pred_idx value: [750], index: 750, number of correct values: 416                , accumulated accuracy: 0.2893
# pred_idx value: [751], index: 751, number of correct values: 417                , accumulated accuracy: 0.2900
# pred_idx value: [752], index: 752, number of correct values: 418                , accumulated accuracy: 0.2907
# pred_idx value: [755], index: 755, number of correct values: 419                , accumulated accuracy: 0.2914
# pred_idx value: [756], index: 756, number of correct values: 420                , accumulated accuracy: 0.2921
# pred_idx value: [758], index: 758, number of correct values: 421                , accumulated accuracy: 0.2928
# pred_idx value: [759], index: 759, number of correct values: 422                , accumulated accuracy: 0.2935
# pred_idx value: [760], index: 760, number of correct values: 423                , accumulated accuracy: 0.2942
# pred_idx value: [761], index: 761, number of correct values: 424                , accumulated accuracy: 0.2949
# pred_idx value: [762], index: 762, number of correct values: 425                , accumulated accuracy: 0.2955
# pred_idx value: [763], index: 763, number of correct values: 426                , accumulated accuracy: 0.2962
# pred_idx value: [765], index: 765, number of correct values: 427                , accumulated accuracy: 0.2969
# pred_idx value: [767], index: 767, number of correct values: 428                , accumulated accuracy: 0.2976
# pred_idx value: [769], index: 769, number of correct values: 429                , accumulated accuracy: 0.2983
# pred_idx value: [772], index: 772, number of correct values: 430                , accumulated accuracy: 0.2990
# pred_idx value: [773], index: 773, number of correct values: 431                , accumulated accuracy: 0.2997
# pred_idx value: [774], index: 774, number of correct values: 432                , accumulated accuracy: 0.3004
# pred_idx value: [775], index: 775, number of correct values: 433                , accumulated accuracy: 0.3011
# ...
# pred_idx value: [1191], index: 1191, number of correct values: 661                , accumulated accuracy: 0.4597
# pred_idx value: [1192], index: 1192, number of correct values: 662                , accumulated accuracy: 0.4604
# pred_idx value: [1194], index: 1194, number of correct values: 663                , accumulated accuracy: 0.4611
# pred_idx value: [1201], index: 1201, number of correct values: 664                , accumulated accuracy: 0.4618
# pred_idx value: [1203], index: 1203, number of correct values: 665                , accumulated accuracy: 0.4624
# pred_idx value: [1204], index: 1204, number of correct values: 666                , accumulated accuracy: 0.4631
# pred_idx value: [1205], index: 1205, number of correct values: 667                , accumulated accuracy: 0.4638
# pred_idx value: [1206], index: 1206, number of correct values: 668                , accumulated accuracy: 0.4645
# pred_idx value: [1209], index: 1209, number of correct values: 669                , accumulated accuracy: 0.4652
# pred_idx value: [1212], index: 1212, number of correct values: 670                , accumulated accuracy: 0.4659
# pred_idx value: [1213], index: 1213, number of correct values: 671                , accumulated accuracy: 0.4666
# pred_idx value: [1215], index: 1215, number of correct values: 672                , accumulated accuracy: 0.4673
# pred_idx value: [1216], index: 1216, number of correct values: 673                , accumulated accuracy: 0.4680
# pred_idx value: [1217], index: 1217, number of correct values: 674                , accumulated accuracy: 0.4687
# pred_idx value: [1218], index: 1218, number of correct values: 675                , accumulated accuracy: 0.4694
# pred_idx value: [1220], index: 1220, number of correct values: 676                , accumulated accuracy: 0.4701
# pred_idx value: [1221], index: 1221, number of correct values: 677                , accumulated accuracy: 0.4708
# pred_idx value: [1223], index: 1223, number of correct values: 678                , accumulated accuracy: 0.4715
# pred_idx value: [1225], index: 1225, number of correct values: 679                , accumulated accuracy: 0.4722
# pred_idx value: [1227], index: 1227, number of correct values: 680                , accumulated accuracy: 0.4729
# pred_idx value: [1229], index: 1229, number of correct values: 681                , accumulated accuracy: 0.4736
# pred_idx value: [1232], index: 1232, number of correct values: 682                , accumulated accuracy: 0.4743
# pred_idx value: [1233], index: 1233, number of correct values: 683                , accumulated accuracy: 0.4750
# pred_idx value: [1235], index: 1235, number of correct values: 684                , accumulated accuracy: 0.4757
# pred_idx value: [1236], index: 1236, number of correct values: 685                , accumulated accuracy: 0.4764
# pred_idx value: [1237], index: 1237, number of correct values: 686                , accumulated accuracy: 0.4771
# pred_idx value: [1238], index: 1238, number of correct values: 687                , accumulated accuracy: 0.4777
# pred_idx value: [1239], index: 1239, number of correct values: 688                , accumulated accuracy: 0.4784
# pred_idx value: [1245], index: 1245, number of correct values: 689                , accumulated accuracy: 0.4791
# pred_idx value: [1249], index: 1249, number of correct values: 690                , accumulated accuracy: 0.4798
# pred_idx value: [1250], index: 1250, number of correct values: 691                , accumulated accuracy: 0.4805
# pred_idx value: [1255], index: 1255, number of correct values: 692                , accumulated accuracy: 0.4812
# pred_idx value: [1256], index: 1256, number of correct values: 693                , accumulated accuracy: 0.4819
# pred_idx value: [1260], index: 1260, number of correct values: 694                , accumulated accuracy: 0.4826
# pred_idx value: [1261], index: 1261, number of correct values: 695                , accumulated accuracy: 0.4833
# pred_idx value: [1264], index: 1264, number of correct values: 696                , accumulated accuracy: 0.4840
# pred_idx value: [1266], index: 1266, number of correct values: 697                , accumulated accuracy: 0.4847
# pred_idx value: [1269], index: 1269, number of correct values: 698                , accumulated accuracy: 0.4854
# pred_idx value: [1270], index: 1270, number of correct values: 699                , accumulated accuracy: 0.4861
# pred_idx value: [1274], index: 1274, number of correct values: 700                , accumulated accuracy: 0.4868
# pred_idx value: [1275], index: 1275, number of correct values: 701                , accumulated accuracy: 0.4875
# pred_idx value: [1277], index: 1277, number of correct values: 702                , accumulated accuracy: 0.4882
# pred_idx value: [1278], index: 1278, number of correct values: 703                , accumulated accuracy: 0.4889
# pred_idx value: [1279], index: 1279, number of correct values: 704                , accumulated accuracy: 0.4896
# pred_idx value: [1283], index: 1283, number of correct values: 705                , accumulated accuracy: 0.4903
# pred_idx value: [1286], index: 1286, number of correct values: 706                , accumulated accuracy: 0.4910
# pred_idx value: [1288], index: 1288, number of correct values: 707                , accumulated accuracy: 0.4917
# pred_idx value: [1289], index: 1289, number of correct values: 708                , accumulated accuracy: 0.4924
# pred_idx value: [1292], index: 1292, number of correct values: 709                , accumulated accuracy: 0.4930
# pred_idx value: [1295], index: 1295, number of correct values: 710                , accumulated accuracy: 0.4937
# pred_idx value: [1296], index: 1296, number of correct values: 711                , accumulated accuracy: 0.4944
# pred_idx value: [1298], index: 1298, number of correct values: 712                , accumulated accuracy: 0.4951
# pred_idx value: [1299], index: 1299, number of correct values: 713                , accumulated accuracy: 0.4958
# pred_idx value: [1300], index: 1300, number of correct values: 714                , accumulated accuracy: 0.4965
# pred_idx value: [1304], index: 1304, number of correct values: 715                , accumulated accuracy: 0.4972
# pred_idx value: [1305], index: 1305, number of correct values: 716                , accumulated accuracy: 0.4979
# pred_idx value: [1307], index: 1307, number of correct values: 717                , accumulated accuracy: 0.4986
# pred_idx value: [1308], index: 1308, number of correct values: 718                , accumulated accuracy: 0.4993
# pred_idx value: [1311], index: 1311, number of correct values: 719                , accumulated accuracy: 0.5000
# pred_idx value: [1312], index: 1312, number of correct values: 720                , accumulated accuracy: 0.5007
# pred_idx value: [1314], index: 1314, number of correct values: 721                , accumulated accuracy: 0.5014
# pred_idx value: [1317], index: 1317, number of correct values: 722                , accumulated accuracy: 0.5021
# pred_idx value: [1319], index: 1319, number of correct values: 723                , accumulated accuracy: 0.5028
# pred_idx value: [1320], index: 1320, number of correct values: 724                , accumulated accuracy: 0.5035
# pred_idx value: [1324], index: 1324, number of correct values: 725                , accumulated accuracy: 0.5042
# pred_idx value: [1325], index: 1325, number of correct values: 726                , accumulated accuracy: 0.5049
# pred_idx value: [1326], index: 1326, number of correct values: 727                , accumulated accuracy: 0.5056
# pred_idx value: [1328], index: 1328, number of correct values: 728                , accumulated accuracy: 0.5063
# pred_idx value: [1329], index: 1329, number of correct values: 729                , accumulated accuracy: 0.5070
# pred_idx value: [1330], index: 1330, number of correct values: 730                , accumulated accuracy: 0.5076
# pred_idx value: [1333], index: 1333, number of correct values: 731                , accumulated accuracy: 0.5083
# pred_idx value: [1334], index: 1334, number of correct values: 732                , accumulated accuracy: 0.5090
# pred_idx value: [1336], index: 1336, number of correct values: 733                , accumulated accuracy: 0.5097
# pred_idx value: [1337], index: 1337, number of correct values: 734                , accumulated accuracy: 0.5104
# pred_idx value: [1338], index: 1338, number of correct values: 735                , accumulated accuracy: 0.5111
# pred_idx value: [1339], index: 1339, number of correct values: 736                , accumulated accuracy: 0.5118
# pred_idx value: [1340], index: 1340, number of correct values: 737                , accumulated accuracy: 0.5125
# pred_idx value: [1341], index: 1341, number of correct values: 738                , accumulated accuracy: 0.5132
# pred_idx value: [1342], index: 1342, number of correct values: 739                , accumulated accuracy: 0.5139
# pred_idx value: [1343], index: 1343, number of correct values: 740                , accumulated accuracy: 0.5146
# pred_idx value: [1346], index: 1346, number of correct values: 741                , accumulated accuracy: 0.5153
# pred_idx value: [1348], index: 1348, number of correct values: 742                , accumulated accuracy: 0.5160
# pred_idx value: [1349], index: 1349, number of correct values: 743                , accumulated accuracy: 0.5167
# pred_idx value: [1350], index: 1350, number of correct values: 744                , accumulated accuracy: 0.5174
# pred_idx value: [1351], index: 1351, number of correct values: 745                , accumulated accuracy: 0.5181
# pred_idx value: [1352], index: 1352, number of correct values: 746                , accumulated accuracy: 0.5188
# pred_idx value: [1353], index: 1353, number of correct values: 747                , accumulated accuracy: 0.5195
# pred_idx value: [1356], index: 1356, number of correct values: 748                , accumulated accuracy: 0.5202
# pred_idx value: [1357], index: 1357, number of correct values: 749                , accumulated accuracy: 0.5209
# pred_idx value: [1358], index: 1358, number of correct values: 750                , accumulated accuracy: 0.5216
# pred_idx value: [1361], index: 1361, number of correct values: 751                , accumulated accuracy: 0.5223
# pred_idx value: [1362], index: 1362, number of correct values: 752                , accumulated accuracy: 0.5229
# pred_idx value: [1363], index: 1363, number of correct values: 753                , accumulated accuracy: 0.5236
# pred_idx value: [1365], index: 1365, number of correct values: 754                , accumulated accuracy: 0.5243
# pred_idx value: [1367], index: 1367, number of correct values: 755                , accumulated accuracy: 0.5250
# pred_idx value: [1369], index: 1369, number of correct values: 756                , accumulated accuracy: 0.5257
# pred_idx value: [1370], index: 1370, number of correct values: 757                , accumulated accuracy: 0.5264
# pred_idx value: [1371], index: 1371, number of correct values: 758                , accumulated accuracy: 0.5271
# pred_idx value: [1372], index: 1372, number of correct values: 759                , accumulated accuracy: 0.5278
# pred_idx value: [1375], index: 1375, number of correct values: 760                , accumulated accuracy: 0.5285
# pred_idx value: [1376], index: 1376, number of correct values: 761                , accumulated accuracy: 0.5292
# pred_idx value: [1377], index: 1377, number of correct values: 762                , accumulated accuracy: 0.5299
# pred_idx value: [1378], index: 1378, number of correct values: 763                , accumulated accuracy: 0.5306
# pred_idx value: [1379], index: 1379, number of correct values: 764                , accumulated accuracy: 0.5313
# pred_idx value: [1380], index: 1380, number of correct values: 765                , accumulated accuracy: 0.5320
# pred_idx value: [1386], index: 1386, number of correct values: 766                , accumulated accuracy: 0.5327
# pred_idx value: [1389], index: 1389, number of correct values: 767                , accumulated accuracy: 0.5334
# pred_idx value: [1391], index: 1391, number of correct values: 768                , accumulated accuracy: 0.5341
# pred_idx value: [1392], index: 1392, number of correct values: 769                , accumulated accuracy: 0.5348
# pred_idx value: [1393], index: 1393, number of correct values: 770                , accumulated accuracy: 0.5355
# pred_idx value: [1394], index: 1394, number of correct values: 771                , accumulated accuracy: 0.5362
# pred_idx value: [1395], index: 1395, number of correct values: 772                , accumulated accuracy: 0.5369
# pred_idx value: [1396], index: 1396, number of correct values: 773                , accumulated accuracy: 0.5376
# pred_idx value: [1398], index: 1398, number of correct values: 774                , accumulated accuracy: 0.5382
# pred_idx value: [1399], index: 1399, number of correct values: 775                , accumulated accuracy: 0.5389
# pred_idx value: [1401], index: 1401, number of correct values: 776                , accumulated accuracy: 0.5396
# pred_idx value: [1402], index: 1402, number of correct values: 777                , accumulated accuracy: 0.5403
# pred_idx value: [1403], index: 1403, number of correct values: 778                , accumulated accuracy: 0.5410
# pred_idx value: [1404], index: 1404, number of correct values: 779                , accumulated accuracy: 0.5417
# pred_idx value: [1407], index: 1407, number of correct values: 780                , accumulated accuracy: 0.5424
# pred_idx value: [1409], index: 1409, number of correct values: 781                , accumulated accuracy: 0.5431
# pred_idx value: [1410], index: 1410, number of correct values: 782                , accumulated accuracy: 0.5438
# pred_idx value: [1411], index: 1411, number of correct values: 783                , accumulated accuracy: 0.5445
# pred_idx value: [1413], index: 1413, number of correct values: 784                , accumulated accuracy: 0.5452
# pred_idx value: [1414], index: 1414, number of correct values: 785                , accumulated accuracy: 0.5459
# pred_idx value: [1415], index: 1415, number of correct values: 786                , accumulated accuracy: 0.5466
# pred_idx value: [1417], index: 1417, number of correct values: 787                , accumulated accuracy: 0.5473
# pred_idx value: [1421], index: 1421, number of correct values: 788                , accumulated accuracy: 0.5480
# pred_idx value: [1422], index: 1422, number of correct values: 789                , accumulated accuracy: 0.5487
# pred_idx value: [1424], index: 1424, number of correct values: 790                , accumulated accuracy: 0.5494
# pred_idx value: [1425], index: 1425, number of correct values: 791                , accumulated accuracy: 0.5501
# pred_idx value: [1426], index: 1426, number of correct values: 792                , accumulated accuracy: 0.5508
# pred_idx value: [1427], index: 1427, number of correct values: 793                , accumulated accuracy: 0.5515
# pred_idx value: [1428], index: 1428, number of correct values: 794                , accumulated accuracy: 0.5522
# pred_idx value: [1429], index: 1429, number of correct values: 795                , accumulated accuracy: 0.5529
# pred_idx value: [1430], index: 1430, number of correct values: 796                , accumulated accuracy: 0.5535
# pred_idx value: [1431], index: 1431, number of correct values: 797                , accumulated accuracy: 0.5542
# pred_idx value: [1432], index: 1432, number of correct values: 798                , accumulated accuracy: 0.5549
# pred_idx value: [1433], index: 1433, number of correct values: 799                , accumulated accuracy: 0.5556
# pred_idx value: [1435], index: 1435, number of correct values: 800                , accumulated accuracy: 0.5563
# pred_idx value: [1436], index: 1436, number of correct values: 801                , accumulated accuracy: 0.5570
# accuracy on test set is 0.557

# %% [markdown]
# **Expected Output**:
#
# ```
# 0.557
# ```
#
# You managed to translate words from one language to another language
# without ever seing them with almost 56% accuracy by using some basic
# linear algebra and learning a mapping of words from one language to another!

# %%
# Test your function
w4_unittest.unittest_test_vocabulary(test_vocabulary)
# Out:
# X shape: (2, 1)
# R shape: (1, 1)
# Y shape: (2, 1)
# pred shape: (2, 1)
# 2
# pred_idx value: [1], index: 1, number of correct values: 1                , accumulated accuracy: 0.5000
# X shape: (4, 2)
# R shape: (2, 2)
# Y shape: (4, 2)
# pred shape: (4, 2)
# 4
# pred_idx value: [2], index: 2, number of correct values: 1                , accumulated accuracy: 0.2500
#  All tests passed

# %% [markdown]
# <a name="3"></a>
# ## 3 - LSH and Document Search
#
# In this part of the assignment, you will implement a more efficient version
# of k-nearest neighbors using locality sensitive hashing.
# You will then apply this to document search.
#
# * Process the tweets and represent each tweet as a vector (represent a
# document with a vector embedding).
# * Use locality sensitive hashing and k nearest neighbors to find tweets
# that are similar to a given tweet.

# %%
# get the positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')
all_tweets = all_positive_tweets + all_negative_tweets

# %% [markdown]
# <a name="3-1"></a>
# ### 3.1 - Getting the Document Embeddings
#
# #### Bag-of-words (BOW) Document Models
# Text documents are sequences of words.
# * The ordering of words makes a difference. For example, sentences "Apple pie is
# better than pepperoni pizza." and "Pepperoni pizza is better than apple pie"
# have opposite meanings due to the word ordering.
# * However, for some applications, ignoring the order of words can allow
# us to train an efficient and still effective model.
# * This approach is called Bag-of-words document model.
#
# #### Document Embeddings
# * Document embedding is created by summing up the embeddings of all words
# in the document.
# * If we don't know the embedding of some word, we can ignore that word.

# %% [markdown]
# <a name="ex-7"></a>
#
# ### Exercise 7 - get_document_embedding
# Complete the `get_document_embedding()` function.
# * The function `get_document_embedding()` encodes entire document as a "document" embedding.
# * It takes in a document (as a string) and a dictionary, `en_embeddings`
# * It processes the document, and looks up the corresponding embedding of each word.
# * It then sums them up and returns the sum of all word vectors of that processed tweet.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> You can handle missing words easier by using the `get()` method of the python dictionary instead of the bracket notation (i.e. "[ ]"). See more about it <a href="https://stackoverflow.com/a/11041421/12816433" >here</a> </li>
#     <li> The default value for missing word should be the zero vector. Numpy will <a href="https://docs.scipy.org/doc/numpy/user/basics.broadcasting.html" > broadcast </a> simple 0 scalar into a vector of zeros during the summation.</li>
#     <li>Alternatively, skip the addition if a word is not in the dictonary. </li>
#     <li>  You can use your `process_tweet()` function which allows you to process the tweet. The function just takes in a tweet and returns a list of words.</li>
# </ul>
# </p>

# %%
# UNQ_C12 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def get_document_embedding(tweet, en_embeddings, process_tweet=process_tweet):
    '''
    Input:
        - tweet: a string
        - en_embeddings: a dictionary of word embeddings
    Output:
        - doc_embedding: sum of all word embeddings in the tweet
    '''
    doc_embedding = np.zeros(300)

    ### START CODE HERE ###
    # process the document into a list of words (process the tweet)
    processed_doc = process_tweet(tweet)
    for word in processed_doc:
        # add the word embedding to the running total for the document embedding
        doc_embedding = doc_embedding + en_embeddings.get(word, 0)
    ### END CODE HERE ###
    return doc_embedding

# %%
# UNQ_C13 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# testing your function
custom_tweet = "RT @Twitter @chapagain Hello There! Have a great day. :) #good #morning http://chapagain.com.np"
tweet_embedding = get_document_embedding(custom_tweet, en_embeddings_subset)
tweet_embedding[-5:]
# Out:
# array([-0.00268555, -0.15378189, -0.55761719, -0.07216644, -0.32263184])

# %% [markdown]
# **Expected output**:
#
# ```
# array([-0.00268555, -0.15378189, -0.55761719, -0.07216644, -0.32263184])
# ```

# %%
# Test your function
w4_unittest.test_get_document_embedding(get_document_embedding)
# Out:
#  All tests passed

# %% [markdown]
# <a name="ex-8"></a>
# ### Exercise 8 - get_document_vecs
#
# #### Store all document vectors into a dictionary
# Now, let's store all the tweet embeddings into a dictionary.
# Implement `get_document_vecs()`

# %%
# UNQ_C14 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def get_document_vecs(all_docs, en_embeddings, get_document_embedding=get_document_embedding):
    '''
    Input:
        - all_docs: list of strings - all tweets in our dataset.
        - en_embeddings: dictionary with words as the keys and their embeddings as the values.
    Output:
        - document_vec_matrix: matrix of tweet embeddings.
        - ind2Doc_dict: dictionary with indices of tweets in vecs as keys and their embeddings as the values.
    '''

    # the dictionary's key is an index (integer) that identifies a specific tweet
    # the value is the document embedding for that document
    ind2Doc_dict = {}

    # this is list that will store the document vectors
    document_vec_l = []

    for i, doc in enumerate(all_docs):

        ### START CODE HERE ###
        # get the document embedding of the tweet
        doc_embedding = get_document_embedding(doc, en_embeddings)

        # save the document embedding into the ind2Tweet dictionary at index i
        ind2Doc_dict[i] = doc_embedding

        # append the document embedding to the list of document vectors
        document_vec_l.append(ind2Doc_dict[i])

        ### END CODE HERE ###

    # convert the list of document vectors into a 2D array (each row is a document vector)
    document_vec_matrix = np.vstack(document_vec_l)

    return document_vec_matrix, ind2Doc_dict

# %%
document_vecs, ind2Tweet = get_document_vecs(all_tweets, en_embeddings_subset)

# %%
# UNQ_C15 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

print(f"length of dictionary {len(ind2Tweet)}")
print(f"shape of document_vecs {document_vecs.shape}")
# Out:
# length of dictionary 10000
# shape of document_vecs (10000, 300)

# %% [markdown]
# ##### Expected Output
# ```
# length of dictionary 10000
# shape of document_vecs (10000, 300)
# ```

# %%
# Test your function. This cell may take some seconds to run.
w4_unittest.test_get_document_vecs(get_document_vecs)
# Out:
#  All tests passed

# %% [markdown]
# <a name="3-2"></a>
# ### 3.2 - Looking up the Tweets
#
# Now you have a vector of dimension (m,d) where `m` is the number of tweets
# (10,000) and `d` is the dimension of the embeddings (300).  Now you
# will input a tweet, and use cosine similarity to see which tweet in our
# corpus is similar to your tweet.

# %%
my_tweet = 'i am sad'
process_tweet(my_tweet)
tweet_embedding = get_document_embedding(my_tweet, en_embeddings_subset)

# %%
# UNQ_C16 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# this gives you a similar tweet as your input.
# this implementation is vectorized...
idx = np.argmax(cosine_similarity(document_vecs, tweet_embedding))
print(all_tweets[idx])
# Out:
# @hanbined sad pray for me :(((

# %% [markdown]
# ##### Expected Output
#
# ```
# @hanbined sad pray for me :(((
# ```

# %% [markdown]
# <a name="3-3"></a>
# ### 3.3 - Finding the most Similar Tweets with LSH
#
# You will now implement locality sensitive hashing (LSH) to identify the most similar tweet.
# * Instead of looking at all 10,000 vectors, you can just search a subset to find
# its nearest neighbors.
#
# Let's say your data points are plotted like this:
#
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='./images/one.png' alt="alternate text" width="width" height="height" style="width:400px;height:200px;" /> Figure 3 </div>
#
# You can divide the vector space into regions and search within one region for nearest neighbors of a given vector.
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='./images/four.png' alt="alternate text" width="width" height="height" style="width:400px;height:200px;" /> Figure 4 </div>

# %%
N_VECS = len(all_tweets)       # This many vectors.
N_DIMS = len(ind2Tweet[1])     # Vector dimensionality.
print(f"Number of vectors is {N_VECS} and each has {N_DIMS} dimensions.")
# Out:
# Number of vectors is 10000 and each has 300 dimensions.

# %% [markdown]
# #### Choosing the number of planes
#
# * Each plane divides the space to $2$ parts.
# * So $n$ planes divide the space into $2^{n}$ hash buckets.
# * We want to organize 10,000 document vectors into buckets so that every bucket has about $~16$ vectors.
# * For that we need $\frac{10000}{16}=625$ buckets.
# * We're interested in $n$, number of planes, so that $2^{n}= 625$. Now, we can calculate $n=\log_{2}625 = 9.29 \approx 10$.

# %%
# The number of planes. We use log2(625) to have ~16 vectors/bucket.
N_PLANES = 10
# Number of times to repeat the hashing to improve the search.
N_UNIVERSES = 25

# %% [markdown]
# <a name="3-4"></a>
# ### 3.4 - Getting the Hash Number for a Vector
#
# For each vector, we need to get a unique number associated to that vector in order to assign it to a "hash bucket".
#
# #### Hyperplanes in Vector Spaces
# * In $3$-dimensional vector space, the hyperplane is a regular plane. In $2$ dimensional vector space, the hyperplane is a line.
# * Generally, the hyperplane is subspace which has dimension $1$ lower than the original vector space has.
# * A hyperplane is uniquely defined by its normal vector.
# * Normal vector $n$ of the plane $\pi$ is the vector to which all vectors in the plane $\pi$ are orthogonal (perpendicular in $3$ dimensional case).
#
# #### Using Hyperplanes to Split the Vector Space
# We can use a hyperplane to split the vector space into $2$ parts.
# * All vectors whose dot product with a plane's normal vector is positive are on one side of the plane.
# * All vectors whose dot product with the plane's normal vector is negative are on the other side of the plane.
#
# #### Encoding Hash Buckets
# * For a vector, we can take its dot product with all the planes, then encode this information to assign the vector to a single hash bucket.
# * When the vector is pointing to the opposite side of the hyperplane than normal, encode it by 0.
# * Otherwise, if the vector is on the same side as the normal vector, encode it by 1.
# * If you calculate the dot product with each plane in the same order for every vector, you've encoded each vector's unique hash ID as a binary number, like [0, 1, 1, ... 0].

# %% [markdown]
# <a name="ex-9"></a>
# ### Exercise 9 - hash_value_of_vector
#
# We've initialized hash table `hashes` for you. It is list of `N_UNIVERSES` matrices, each describes its own hash table. Each matrix has `N_DIMS` rows and `N_PLANES` columns. Every column of that matrix is a `N_DIMS`-dimensional normal vector for each of `N_PLANES` hyperplanes which are used for creating buckets of the particular hash table.
#
# *Exercise*: Your task is to complete the function `hash_value_of_vector` which places vector `v` in the correct hash bucket.
#
# * First multiply your vector `v`, with a corresponding plane. This will give you a vector of dimension $(1,\text{N_planes})$.
# * You will then convert every element in that vector to 0 or 1.
# * You create a hash vector by doing the following: if the element is negative, it becomes a 0, otherwise you change it to a 1.
# * You then compute the unique number for the vector by iterating over `N_PLANES`
# * Then you multiply $2^i$ times the corresponding bit (0 or 1).
# * You will then store that sum in the variable `hash_value`.
#
# **Intructions:** Create a hash for the vector in the function below.
# Use this formula:
#
# $$ hash = \sum_{i=0}^{N-1} \left( 2^{i} \times h_{i} \right) $$

# %% [markdown]
# #### Create the sets of planes
# * Create multiple (25) sets of planes (the planes that divide up the region).
# * You can think of these as 25 separate ways of dividing up the vector space with a different set of planes.
# * Each element of this list contains a matrix with 300 rows (the word vector have 300 dimensions), and 10 columns (there are 10 planes in each "universe").

# %%
np.random.seed(0)
planes_l = [np.random.normal(size=(N_DIMS, N_PLANES))
            for _ in range(N_UNIVERSES)]

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> numpy.squeeze() removes unused dimensions from an array; for instance, it converts a (10,1) 2D array into a (10,) 1D array</li>
# </ul>
# </p>

# %%
# UNQ_C17 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def hash_value_of_vector(v, planes):
    """Create a hash for a vector; hash_id says which random hash to use.
    Input:
        - v:  vector of tweet. It's dimension is (1, N_DIMS)
        - planes: matrix of dimension (N_DIMS, N_PLANES) - the set of planes that divide up the region
    Output:
        - res: a number which is used as a hash for your vector

    """
    ### START CODE HERE ###
    # for the set of planes,
    # calculate the dot product between the vector and the matrix containing the planes
    # remember that planes has shape (300, 10)
    # The dot product will have the shape (1,10)    
    dot_product = np.dot(v, planes)
        
    # get the sign of the dot product (1,10) shaped vector
    sign_of_dot_product = np.sign(dot_product)

    # set h to be false (eqivalent to 0 when used in operations) if the sign is negative,
    # and true (equivalent to 1) if the sign is positive (1,10) shaped vector
    # if the sign is 0, i.e. the vector is in the plane, consider the sign to be positive
    h = sign_of_dot_product >= 0

    # remove extra un-used dimensions (convert this from a 2D to a 1D array)
    h = h.squeeze()

    # initialize the hash value to 0
    hash_value = 0

    n_planes = planes.shape[1]
    for i in range(n_planes):
        # increment the hash value by 2^i * h_i        
        hash_value += (2**i)*h[i]
        
    ### END CODE HERE ###

    # cast hash_value as an integer
    hash_value = int(hash_value)

    return hash_value

# %%
# UNQ_C18 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

np.random.seed(0)
idx = 0
planes = planes_l[idx]  # get one 'universe' of planes to test the function
vec = np.random.rand(1, 300)
print(f" The hash value for this vector,",
      f"and the set of planes at index {idx},",
      f"is {hash_value_of_vector(vec, planes)}")
# Out:
#  The hash value for this vector, and the set of planes at index 0, is 768

# %% [markdown]
# ##### Expected Output
#
# ```
# The hash value for this vector, and the set of planes at index 0, is 768
# ```

# %%
# Test your function
w4_unittest.test_hash_value_of_vector(hash_value_of_vector)
# Out:
#  All tests passed

# %% [markdown]
# <a name="3-5"></a>
# ### 3.5 - Creating a Hash Table
#
# <a name="ex-10"></a>
# ### Exercise 10 - make_hash_table
#
# Given that you have a unique number for each vector (or tweet), You now want to create a hash table. You need a hash table, so that given a hash_id, you can quickly look up the corresponding vectors. This allows you to reduce your search by a significant amount of time.
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='./images/table.png' alt="alternate text" width="width" height="height" style="width:500px;height:200px;" />  </div>
#
# We have given you the `make_hash_table` function, which maps the tweet vectors to a bucket and stores the vector there. It returns the `hash_table` and the `id_table`. The `id_table` allows you know which vector in a certain bucket corresponds to what tweet.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> a dictionary comprehension, similar to a list comprehension, looks like this: `{i:0 for i in range(10)}`, where the key is 'i' and the value is zero for all key-value pairs. </li>
# </ul>
# </p>

# %%
# UNQ_C19 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)

# This is the code used to create a hash table: 
# This function is already implemented for you. Feel free to read over it.

### YOU CANNOT EDIT THIS CELL

def make_hash_table(vecs, planes, hash_value_of_vector=hash_value_of_vector):
    """
    Input:
        - vecs: list of vectors to be hashed.
        - planes: the matrix of planes in a single "universe", with shape (embedding dimensions, number of planes).
    Output:
        - hash_table: dictionary - keys are hashes, values are lists of vectors (hash buckets)
        - id_table: dictionary - keys are hashes, values are list of vectors id's
                            (it's used to know which tweet corresponds to the hashed vector)
    """
    # number of planes is the number of columns in the planes matrix
    num_of_planes = planes.shape[1]

    # number of buckets is 2^(number of planes)
    # ALTERNATIVE SOLUTION COMMENT:
    # num_buckets = pow(2, num_of_planes)
    num_buckets = 2**num_of_planes

    # create the hash table as a dictionary.
    # Keys are integers (0,1,2.. number of buckets)
    # Values are empty lists
    hash_table = {i: [] for i in range(num_buckets)}

    # create the id table as a dictionary.
    # Keys are integers (0,1,2... number of buckets)
    # Values are empty lists
    id_table = {i: [] for i in range(num_buckets)}

    # for each vector in 'vecs'
    for i, v in enumerate(vecs):
        # calculate the hash value for the vector
        h = hash_value_of_vector(v, planes)

        # store the vector into hash_table at key h,
        # by appending the vector v to the list at key h
        hash_table[h].append(v) # @REPLACE None

        # store the vector's index 'i' (each document is given a unique integer 0,1,2...)
        # the key is the h, and the 'i' is appended to the list at key h
        id_table[h].append(i) # @REPLACE None

    return hash_table, id_table

# %%
# UNQ_C20 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything
planes = planes_l[0]  # get one 'universe' of planes to test the function
tmp_hash_table, tmp_id_table = make_hash_table(document_vecs, planes)

print(f"The hash table at key 0 has {len(tmp_hash_table[0])} document vectors")
print(f"The id table at key 0 has {len(tmp_id_table[0])} document indices")
print(f"The first 5 document indices stored at key 0 of id table are {tmp_id_table[0][0:5]}")
# Out:
# The hash table at key 0 has 3 document vectors
# The id table at key 0 has 3 document indices
# The first 5 document indices stored at key 0 of id table are [3276, 3281, 3282]

# %% [markdown]
# ##### Expected output
# ```
# The hash table at key 0 has 3 document vectors
# The id table at key 0 has 3 document indices
# The first 5 document indices stored at key 0 of id table are [3276, 3281, 3282]
# ```

# %%
# Test your function
w4_unittest.test_make_hash_table(make_hash_table)
# Out:
#  All tests passed

# %% [markdown]
# <a name="3-6"></a>
# ### 3.6 - Creating all Hash Tables
#
# You can now hash your vectors and store them in a hash table that
# would allow you to quickly look up and search for similar vectors.
# Run the cell below to create the hashes. By doing so, you end up having
# several tables which have all the vectors. Given a vector, you then
# identify the buckets in all the tables.  You can then iterate over the
# buckets and consider much fewer vectors. The more tables you use, the
# more accurate your lookup will be, but also the longer it will take.

# %%
# Creating the hashtables
def create_hash_id_tables(n_universes):
    hash_tables = []
    id_tables = []
    for universe_id in range(n_universes):  # there are 25 hashes
        print('working on hash universe #:', universe_id)
        planes = planes_l[universe_id]
        hash_table, id_table = make_hash_table(document_vecs, planes)
        hash_tables.append(hash_table)
        id_tables.append(id_table)
    
    return hash_tables, id_tables

hash_tables, id_tables = create_hash_id_tables(N_UNIVERSES)
# Out:
# working on hash universe #: 0
# working on hash universe #: 1
# working on hash universe #: 2
# working on hash universe #: 3
# working on hash universe #: 4
# working on hash universe #: 5
# working on hash universe #: 6
# working on hash universe #: 7
# working on hash universe #: 8
# working on hash universe #: 9
# working on hash universe #: 10
# working on hash universe #: 11
# working on hash universe #: 12
# working on hash universe #: 13
# working on hash universe #: 14
# working on hash universe #: 15
# working on hash universe #: 16
# working on hash universe #: 17
# working on hash universe #: 18
# working on hash universe #: 19
# working on hash universe #: 20
# working on hash universe #: 21
# working on hash universe #: 22
# working on hash universe #: 23
# working on hash universe #: 24

# %% [markdown]
# #### Approximate K-NN
#
# <a name="ex-11"></a>
# ### Exercise 11 - approximate_knn
#
# Implement approximate K nearest neighbors using locality sensitive hashing,
# to search for documents that are similar to a given document at the
# index `doc_id`.
#
# ##### Inputs
# * `doc_id` is the index into the document list `all_tweets`.
# * `v` is the document vector for the tweet in `all_tweets` at index `doc_id`.
# * `planes_l` is the list of planes (the global variable created earlier).
# * `k` is the number of nearest neighbors to search for.
# * `num_universes_to_use`: to save time, we can use fewer than the total
# number of available universes.  By default, it's set to `N_UNIVERSES`,
# which is $25$ for this assignment.
# * `hash_tables`: list with hash tables for each universe.
# * `id_tables`: list with id tables for each universe.
#
# The `approximate_knn` function finds a subset of candidate vectors that
# are in the same "hash bucket" as the input vector 'v'.  Then it performs
# the usual k-nearest neighbors search on this subset (instead of searching
# through all 10,000 tweets).

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> There are many dictionaries used in this function.  Try to print out planes_l, hash_tables, id_tables to understand how they are structured, what the keys represent, and what the values contain.</li>
#     <li> To remove an item from a list, use `.remove()` </li>
#     <li> To append to a list, use `.append()` </li>
#     <li> To add to a set, use `.add()` </li>
# </ul>
# </p>

# %%
# UNQ_C21 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# This is the code used to do the fast nearest neighbor search. Feel free to go over it
def approximate_knn(doc_id, v, planes_l, hash_tables, id_tables, k=1, num_universes_to_use=25, hash_value_of_vector=hash_value_of_vector):
    """Search for k-NN using hashes."""
    #assert num_universes_to_use <= N_UNIVERSES

    # Vectors that will be checked as possible nearest neighbor
    vecs_to_consider_l = list()

    # list of document IDs
    ids_to_consider_l = list()

    # create a set for ids to consider, for faster checking if a document ID already exists in the set
    ids_to_consider_set = set()

    # loop through the universes of planes
    for universe_id in range(num_universes_to_use):

        # get the set of planes from the planes_l list, for this particular universe_id
        planes = planes_l[universe_id]

        # get the hash value of the vector for this set of planes
        hash_value = hash_value_of_vector(v, planes)

        # get the hash table for this particular universe_id
        hash_table = hash_tables[universe_id]

        # get the list of document vectors for this hash table, where the key is the hash_value
        document_vectors_l = hash_table[hash_value]

        # get the id_table for this particular universe_id
        id_table = id_tables[universe_id]

        # get the subset of documents to consider as nearest neighbors from this id_table dictionary
        new_ids_to_consider = id_table[hash_value]

        ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###

        # loop through the subset of document vectors to consider
        for i, new_id in enumerate(new_ids_to_consider):
            
            if doc_id == new_id:
                continue

            # if the document ID is not yet in the set ids_to_consider...
            if new_id not in ids_to_consider_set:
                # access document_vectors_l list at index i to get the embedding
                # then append it to the list of vectors to consider as possible nearest neighbors
                document_vector_at_i = document_vectors_l[i]
                vecs_to_consider_l.append(document_vector_at_i)

                # append the new_id (the index for the document) to the list of ids to consider
                ids_to_consider_l.append(new_id)

                # also add the new_id to the set of ids to consider
                # (use this to check if new_id is not already in the IDs to consider)
                ids_to_consider_set.add(new_id)

        ### END CODE HERE ###

    # Now run k-NN on the smaller set of vecs-to-consider.
    print("Fast considering %d vecs" % len(vecs_to_consider_l))

    # convert the vecs to consider set to a list, then to a numpy array
    vecs_to_consider_arr = np.array(vecs_to_consider_l)

    # call nearest neighbors on the reduced list of candidate vectors
    nearest_neighbor_idx_l = nearest_neighbor(v, vecs_to_consider_arr, k=k)

    # Use the nearest neighbor index list as indices into the ids to consider
    # create a list of nearest neighbors by the document ids
    nearest_neighbor_ids = [ids_to_consider_l[idx]
                            for idx in nearest_neighbor_idx_l]

    return nearest_neighbor_ids

# %%
#document_vecs, ind2Tweet
doc_id = 0
doc_to_search = all_tweets[doc_id]
vec_to_search = document_vecs[doc_id]

# %%
# UNQ_C22 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# Sample
nearest_neighbor_ids = approximate_knn(
    doc_id, vec_to_search, planes_l, hash_tables, id_tables, k=3, num_universes_to_use=5)
# Out:
# Fast considering 77 vecs

# %%
print(f"Nearest neighbors for document {doc_id}")
print(f"Document contents: {doc_to_search}")
print("")

for neighbor_id in nearest_neighbor_ids:
    print(f"Nearest neighbor at document id {neighbor_id}")
    print(f"document contents: {all_tweets[neighbor_id]}")
# Out:
# Nearest neighbors for document 0
# Document contents: #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# Nearest neighbor at document id 51
# document contents: #FollowFriday @France_Espana @reglisse_menthe @CCI_inter for being top engaged members in my community this week :)
# Nearest neighbor at document id 2478
# document contents: #ShareTheLove @oymgroup @musicartisthere for being top HighValue members this week :) @nataliavas http://t.co/IWSDMtcayt
# Nearest neighbor at document id 105
# document contents: #FollowFriday @straz_das @DCarsonCPA @GH813600 for being top engaged members in my community this week :)

# %%
# Test your function
w4_unittest.test_approximate_knn(approximate_knn, hash_tables, id_tables)
# Out:
# Fast considering 77 vecs
# Fast considering 153 vecs
#  All tests passed

# %% [markdown]
# # 4 Conclusion
# Congratulations - Now you can look up vectors that are similar to the
# encoding of your tweet using LSH!
